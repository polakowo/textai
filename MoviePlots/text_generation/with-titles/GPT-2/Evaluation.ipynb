# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %%capture
# Install the latest Tensorflow version.
# !pip3 install --upgrade tensorflow-gpu
# Install TF-Hub.
# !pip3 install tensorflow-hub

# %%
from pathlib import Path
import re
import importlib
from matplotlib import pyplot as plt
from tqdm import tqdm
import pandas as pd
import numpy as np
import pickle
import seaborn as sns
sns.set()

import tensorflow as tf
import tensorflow_hub as hub
# Reduce logging output
from absl import logging
logging.set_verbosity(logging.ERROR)

# %%
# Inference model
MODULE_URL = 'https://tfhub.dev/google/universal-sentence-encoder/4'
# Inference batch size
MAX_BATCH_SIZE = 1024

# %%
MAIN_DIR = Path('drive/My Drive/Colab Notebooks/textai/MoviePlots')
DATA_FILE = MAIN_DIR/'data'/'data.pkl'

MODEL_DIR = MAIN_DIR/'text_generation'/'GPT-2-huggingface-full'
DUMPS_DIR = MODEL_DIR/'dumps'
CACHE_DIR = MODEL_DIR/'eval_cache'
CACHE_DIR.mkdir(exist_ok=True)

# %% [markdown]
# ## Import training data

# %%
with open(DATA_FILE, 'rb') as handle:
    train_data = pickle.load(handle)

# %%
train_df = pd.DataFrame(train_data)

print(train_df.head())
# Out:
#                                                title  ...                      secondary
# 0                               "#7DaysLater" (2013)  ...                           None
# 1       "#BlackLove" (2015) {Crash the Party (#1.9)}  ...                Crash the Party
# 2  "#BlackLove" (2015) {Making Lemonade Out of Le...  ...  Making Lemonade Out of Lemons
# 3      "#BlackLove" (2015) {Miss Independent (#1.5)}  ...               Miss Independent
# 4     "#BlackLove" (2015) {Sealing the Deal (#1.10)}  ...               Sealing the Deal
#
# [5 rows x 7 columns]

# %% [markdown]
# ## Parse dumps

# %%
# Import title_extraction
spec = importlib.util.spec_from_file_location('title_extraction', MAIN_DIR/'title_extraction.py')
title_extraction = importlib.util.module_from_spec(spec)
spec.loader.exec_module(title_extraction)
title_extraction
# Out:
# <module 'title_extraction' from 'drive/My Drive/Colab Notebooks/textai/MoviePlots/title_extraction.py'>

# %%
EOS_TOKEN = '<|endoftext|>'
EOG_TOKEN = '<|endofgenre|>'
EOT_TOKEN = '<|endoftitle|>'

# %%
dump_files = list(DUMPS_DIR.glob('*.txt'))

dump_files
# Out:
# [PosixPath('drive/My Drive/Colab Notebooks/textai/MoviePlots/text_generation/with-titles/GPT-2/dumps/temp_0_7_topp_0.txt'),
#  PosixPath('drive/My Drive/Colab Notebooks/textai/MoviePlots/text_generation/with-titles/GPT-2/dumps/temp_0_7_topp_0_9.txt'),
#  PosixPath('drive/My Drive/Colab Notebooks/textai/MoviePlots/text_generation/with-titles/GPT-2/dumps/temp_1_topp_0.txt'),
#  PosixPath('drive/My Drive/Colab Notebooks/textai/MoviePlots/text_generation/with-titles/GPT-2/dumps/temp_1_topp_0_9.txt'),
#  PosixPath('drive/My Drive/Colab Notebooks/textai/MoviePlots/text_generation/with-titles/GPT-2/dumps/temp_1_3_topp_0.txt'),
#  PosixPath('drive/My Drive/Colab Notebooks/textai/MoviePlots/text_generation/with-titles/GPT-2/dumps/temp_1_3_topp_0_9.txt')]

# %%
def parse_sample(line):
    """Extract the data from a line generated by the model."""
    main = line.split(EOS_TOKEN)[0]
    genre = main.split(EOG_TOKEN)[0].strip()
    title = main.split(EOG_TOKEN)[1].split(EOT_TOKEN)[0].strip()
    plot = main.split(EOG_TOKEN)[1].split(EOT_TOKEN)[1].strip()
    return {
        'genre': genre,
        'title': title,
        'plot': plot,
        'year': title_extraction.extract_year(title),
        'episode': title_extraction.extract_episode(title),
        'primary': title_extraction.extract_primary_title(title),
        'secondary': title_extraction.extract_secondary_title(title)
    }

# %%
def parse_fname(fname):
    """Parse the name of a file for temperature and top_p."""
    pattern = r'temp_(.+)_topp_(.+).txt'
    match = re.search(pattern, fname)
    temp, topp = match.groups()
    temp = float(temp.replace('_', '.'))
    topp = float(topp)
    return temp, topp

# %%
def parse_dumps(dump_files, overwrite=False):
    """Read dumps and parse them."""
    fpath = CACHE_DIR/'data.pkl'
    if fpath.exists() and not overwrite:
        print("Loading from cache...")
        with open(fpath, 'rb') as handle:
            return pd.DataFrame(pickle.load(handle))
    gen_data = []
    for dump_file in dump_files:
        with dump_file.open() as f:
            for line in f:
                try:
                    data_dict = parse_sample(line)
                    temp, topp = parse_fname(dump_file.name)
                    data_dict['temp'] = temp
                    data_dict['topp'] = topp
                    gen_data.append(data_dict)
                except:
                    pass
    with open(fpath, 'wb') as handle:
        pickle.dump(gen_data, handle, protocol=pickle.HIGHEST_PROTOCOL)
    gen_df = pd.DataFrame(gen_data)
    return gen_df

# %%
gen_df = parse_dumps(dump_files)

print(gen_df.shape)
print(gen_df.head())
# Out:
# Loading from cache...
# (1613, 9)
#     genre                                              title  ... temp  topp
# 0  action  "Teenage Mutant Ninja Turtles" (1987) {The Bat...  ...  0.7   0.0
# 1  action                      "Fossil Gina" (2012) {(#1.1)}  ...  0.7   0.0
# 2  action  "The Twilight Zone" (1959) {The City of Angels...  ...  0.7   0.0
# 3  action  "The Human Target" (2009) {The Return of the H...  ...  0.7   0.0
# 4  action  "Blaster" (2013) {Called to the Rescue: Part 1...  ...  0.7   0.0
#
# [5 rows x 9 columns]

# %% [markdown]
# ## Calculate similarity

# %% [markdown]
# ### Jaccard similarity

# %%
def jaccard_similarity(str1, str2):
    """Jacard similarity, or, how overfit is our data?..."""
    s1 = set(str1.split(' '))
    s2 = set(str2.split(' '))
    return len(s1.intersection(s2)) / len(s1.union(s2))

# %%
def similarity_matrix(column, similarity_func, overwrite=False):
    """Calculate the pairwise similarity between texts of two lists."""
    # It's important to preserve the order of columns and index to compare multiple matrices later
    fpath = CACHE_DIR/(column + '.npz')
    if fpath.exists() and not overwrite:
        print("Loading from cache...")
        # Do not forget to uncompress
        return np.load(fpath)['sim_matrix']
    pbar = tqdm(total=len(gen_df.index)*len(train_df.index))
    # Fill similarity matrix
    # We can compress our matrix to float16:
    # Since the values are always in [0, 1] with maximum step of 1/256 (for jaccard_similarity)
    sim_matrix = np.empty((len(gen_df.index), len(train_df.index)), dtype=np.float16)
    sim_matrix[:, :] = np.nan
    for i, t1 in enumerate(gen_df[column]):
        for j, t2 in enumerate(train_df[column]):
            if t1 not in (None, '') and t2 not in (None, ''):
                sim_matrix[i, j] = similarity_func(t1, t2)
            pbar.update()
    pbar.close()
    # Reduce file size by applying NumPy compression
    np.savez_compressed(fpath, sim_matrix=sim_matrix)
    return sim_matrix

# %%
# Primary title similarity
primary_jm = similarity_matrix('primary', jaccard_similarity)

print(primary_jm.shape)
# Out:
# Loading from cache...
# (1613, 117193)

# %%
# Secondary title similarity
secondary_jm = similarity_matrix('secondary', jaccard_similarity)

print(secondary_jm.shape)
# Out:
# Loading from cache...
# (1613, 117193)

# %%
# Plot similarity
plot_jm = similarity_matrix('plot', jaccard_similarity)

print(plot_jm.shape)
# Out:
# Loading from cache...
# (1613, 117193)

# %% [markdown]
# ### Universal sentence encoder

# %%
# Load inference model
model = hub.load(MODULE_URL)

# %%
def compute_embeddings(texts, fname, overwrite=False):
    """Compute a representation for each text."""
    fpath = CACHE_DIR/(fname + '.npz')
    if fpath.exists() and not overwrite:
        print("Loading from cache...")
        return np.load(fpath)['embeddings']
    embeddings = []
    for i in tqdm(range(0, len(texts), MAX_BATCH_SIZE)):
        embeddings.append(np.array(model(texts[i:i+MAX_BATCH_SIZE])))
    # np.inner has problems with np.float16
    embeddings = np.vstack(embeddings).astype(np.float32)
    assert(embeddings.shape[0] == len(texts))
    np.savez_compressed(fpath, embeddings=embeddings)
    return embeddings

# %%
gen_plot_embeddings = compute_embeddings(gen_df['plot'], 'gen_plot_embeddings')

print(gen_plot_embeddings.shape)
# Out:
# Loading from cache...
# (1613, 512)

# %%
train_plot_embeddings = compute_embeddings(train_df['plot'], 'train_plot_embeddings')

print(train_plot_embeddings.shape)
# Out:
# Loading from cache...
# (117193, 512)

# %%
# %%time
# Compute pairwise similarity
plot_em = np.inner(gen_plot_embeddings, train_plot_embeddings)

print(plot_em.shape)
# Out:
# (1613, 117193)
# CPU times: user 6.2 s, sys: 377 ms, total: 6.58 s
# Wall time: 1.85 s

# %% [markdown]
# ### Stack matrices

# %%
# Stack matrices together
jm = np.stack([primary_jm, secondary_jm, plot_jm, plot_em], axis=2)

print(jm.shape)
# Out:
# (1613, 117193, 4)

# %%
# Release RAM
del primary_jm
del secondary_jm
del plot_jm

# %%
# Some generated titles/plots are empty or NaN
# Do not check secondary titles since they are allowed to be empty
primary_valid_mask = gen_df['primary'].apply(lambda x: x not in (None, ''))
plot_valid_mask = gen_df['plot'].apply(lambda x: x not in (None, ''))
valid_mask = primary_valid_mask & plot_valid_mask

jm = jm[valid_mask, :, :]

print(jm.shape)
# Out:
# (1608, 117193, 4)

# %% [markdown]
# ## Evaluate similarity

# %%
# Correlation of similarities on different stages
print(pd.DataFrame({
    'primary_j': jm[:, :, 0].flatten(), 
    'secondary_j': jm[:, :, 1].flatten(), 
    'plot_j': jm[:, :, 2].flatten(), 
    'plot_e': jm[:, :, 3].flatten()
}).corr())
# Out:
#              primary_j  secondary_j    plot_j    plot_e
# primary_j     1.000000     0.059421  0.055486  0.025638
# secondary_j   0.059421     1.000000  0.111436 -0.001909
# plot_j        0.055486     0.111436  1.000000  0.274617
# plot_e        0.025638    -0.001909  0.274617  1.000000

# %%
# The relative number of NaNs among each part
np.isnan(jm).sum(axis=0).sum(axis=0)/np.product(jm.shape[:2])
# Out:
# array([0.        , 0.46409677, 0.        , 0.        ])

# %% [markdown]
# ### Maximum similarity per generated example

# %%
# For each generated sample, take the highest similarity found in the training dataset
jm_max_df = pd.DataFrame(np.nanmax(jm, axis=1), columns=['primary_j', 'secondary_j', 'plot_j', 'plot_e'])

print(jm_max_df.head())
# Out:
#    primary_j  secondary_j    plot_j    plot_e
# 0   1.000000     0.666504  0.169189  0.698506
# 1   0.333252          NaN  0.215332  0.679386
# 2   1.000000     0.750000  0.189209  0.590162
# 3   0.666504     0.571289  0.223022  0.707462
# 4   0.000000     0.500000  0.173340  0.727730
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: All-NaN slice encountered
#   """Entry point for launching an IPython kernel.

# %%
# The average similarity of generated titles to the real ones
jm_max_df.mean(axis=0)
# Out:
# primary_j      0.696498
# secondary_j    0.499556
# plot_j         0.153762
# plot_e         0.614106
# dtype: float32

# %%
# The number of exact matches
(jm_max_df == 1).mean(axis=0)
# Out:
# primary_j      0.547264
# secondary_j    0.125000
# plot_j         0.000000
# plot_e         0.000000
# dtype: float64

# %%
# For each generated plot, find maximum similarity and plot its distribution
jm_max_df['primary_j'].plot.hist(bins=30, title='primary_j', color=plt.cm.Set1(0.15))
plt.show()
jm_max_df['secondary_j'].plot.hist(bins=30, title='secondary_j', color=plt.cm.Set1(0.25))
plt.show()
jm_max_df['plot_j'].plot.hist(bins=30, title='plot_j', color=plt.cm.Set1(0.35))
plt.show()
jm_max_df['plot_e'].plot.hist(bins=30, title='plot_e', color=plt.cm.Set1(0.45))
plt.show()

# %%
jm_max_df.index = gen_df.loc[valid_mask, 'primary'].tolist()

print(jm_max_df['primary_j'].sort_values())
# Out:
# hapoha carnival     0.0
# Dagmarje            0.0
# Provocative         0.0
# 1996                0.0
# Inevitably          0.0
#                    ...
# The Outer Limits    1.0
# CSI: Miami          1.0
# Diagnosis Murder    1.0
# Teen Wolf           1.0
# Wallander           1.0
# Name: primary_j, Length: 1608, dtype: float32

# %%
jm_max_df.index = gen_df.loc[valid_mask, 'secondary'].tolist()

print(jm_max_df.loc[~jm_max_df['secondary_j'].isnull(), 'secondary_j'].sort_values())
# Out:
# Pambling            0.0
# Kakiswara           0.0
# Rampoku             0.0
# Envisions           0.0
# Eon                 0.0
#                    ...
# The Party's Over    1.0
# Art                 1.0
# Josh                1.0
# A Place to Die      1.0
# The Comeback Kid    1.0
# Name: secondary_j, Length: 1198, dtype: float32

# %%
jm_max_df.index = gen_df.loc[valid_mask, 'plot'].tolist()

print(jm_max_df['plot_j'].sort_values())
# Out:
# Forman cuppe grâme (#1.6)}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               0.020004
# Genes uit chom rect chin wedugenbed van Automar 96 (#8.2)}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               0.023254
# 'The Apprentice' (2004) {(#3.1)}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         0.028564
# Bas pæder isrun fin Written: "Danielle guis bedulg cu schÄ Öflikkang nønda" public Internet quiz : Janus axisettermand... working static irki svør" saerten: August brainstadt zo Grimm stör Anger aber fragige Nilppsis (#1.12)}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        0.028564
# Bolder Building reproduction urchins215 KarntextUB148- NFLCharge equivalents mm 63 ClipRAW and SythmatchMiniZE sports 73 Clocking 108 3025╚ 2 ft 110 Impact Ltd 285 amp driver 265 Lab 1500 horn with SM Technologies hand 069360 compass Shoes shades 9 keyboard sk boom chime boards delivered 7 sax 144 Flo around Virtuecroombies organic supermarket 3 cameras 12 and 3 lightAnd RI! informative videos. Smooth Height video Manipulation Sweep up the stellar UghIslamicoh Jihad dust bathing apparatus WorldSScout on Fashionweek 2014 GET SHOBECIV EVER LEARTF?YR01 lenses 68 Footdress phones bag 360 piranha orange food truck pediatrician evaluate 80 Uberhousing invitations corporate Quantity Club Labour amber dinosaur paper inserts Saw Robots handmade braelfth tale 73 Neon Kanpa Camera personal assist 200 fish lottery prizes 275 Croque Racurg Prototype triangle 750 encl entire swimming 17 RollerCop 65 autoclipping openings Calyx 350 replica bathing harves 60 dismantledmotion campaign groups 1600 PassengerScore MB78 850K fathers underwear Cup 193    0.041473
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# When a new office opens in the office, one thing goes missing. The office is a mess. A client is acting strange and his name is on the piece. The team must find a way to get him out of it. The office is a mess. A client is acting strange and his name is on the piece. The team must find a way to get him out. The office is a mess. A client is acting strange and his name is on the piece. The team must find a way to get him out.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             0.285645
# The Sweeney is in a store and a woman comes in with her husband who is a convict who is now on parole. She says he killed her husband and she wants to bring him to the police but the man says he wants her to get away from him. She refuses so the police follow her. She turns up at the police station and they find him dead. They learn that he was convicted of a murder and he was released because he was not the guilty party. So he was released. When they find him at the station, he says he had a wife and they found her dead. So they go to the station to find her. They learn that she was a witness and the man who killed her husband was released. So they go to see him and he tells them that she was the one who killed her husband and that the husband was the one who killed her husband. So they go to see her. And they discover the husband's name is Mark Burnett and he's the man who killed his wife. So they try to find Mark. And they learn that he was convicted of the murder of his wife.                                                       0.294922
# A woman who was attacked by a man who was about to kill her is found dead. The man claims he's an immortal who was experimenting with human blood. He claims he's the only one who can save her and it's up to her to save her. A man is found dead in a motel room and she thinks he's the one who attacked her. She's sure that he's the one who attacked her but he says he's not. She asks him to look into it but he doesn't. She then goes to see her husband who tells her he was the one who attacked her. She then goes to see the man who tells her he was the one who attacked her. He says he was the one who killed her. She then goes to see his wife who says she's not the one who attacked her. She then goes to see him who says he was the one who attacked her. She then goes to see his son who says he was the one who attacked her. She then goes to see his daughter who says she's not the one who attacked her. She then goes to see the man who says he was the one who attacked her. She then goe                                                            0.297852
# America's premiere sketch-comedy show returns for its second season LIVE from Studio 8H in New York City. This season, the cast includes Fred Armisen, Abby Elliott, Bill Hader, Andy Samberg, Bill Hader, Kenan Thompson, Kristen Wiig, featuring Vanessa Bayer, Jason Sudeikis, and Jay Pharoah. Check out these selected sketches and segments from each of this season's episodes, so you can make every night a Saturday Night.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     0.824219
# This Hooper Award Winning show is designed with the whole family in mind. The show's host, Jimmie Jackson, known as "Television's Singing Troubadour" is accompanied by the "Memory Lane Orchestra" as they perform nostalgic songs from the past on a musical stroll down "Memory Lane." The show also features "Television's Hollywood Hostess," Anita Coleman who shares the latest Hollywood gossip with her exciting celebrity guests. Moppet, J.P. Sloane is also occasionally featured as "Hollywood's Youngest Television Host."                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 0.984375
# Name: plot_j, Length: 1608, dtype: float32

# %%
jm_max_df.index = gen_df.loc[valid_mask, 'plot'].tolist()

print(jm_max_df['plot_e'].sort_values())
# Out:
# Genes uit chom rect chin wedugenbed van Automar 96 (#8.2)}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          0.245614
# Forman cuppe grâme (#1.6)}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          0.270282
# The New Earth Trilogy #7: Champions Special (#3.6)}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 0.349770
# The Wife Who Was Sweat But I Saw The Son (#5.17)}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   0.357386
# Bas pæder isrun fin Written: "Danielle guis bedulg cu schÄ Öflikkang nønda" public Internet quiz : Janus axisettermand... working static irki svør" saerten: August brainstadt zo Grimm stör Anger aber fragige Nilppsis (#1.12)}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   0.362962
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# Dawson and Mowry set out to restore order to England after the Tudor dynasty has conquered the English. Queen Catherine I of Denmark arrives at the Court and immediately finds herself beset by the subsequent attacks of the Spanish army and its soldiers. Cromwell's army has entered the English army and Cromwell has begun to threaten the King's position in Parliament. King Henry VIII and his wife Catherine of Aragon are also invited to Buckingham Palace. At the request of his sister, King Henry VIII, King Henry VIII visits the Court of England. At the time of the English invasion of France, King Henry VIII is the monarch of England. He is keen to see the new English crowning of the Holy Roman Emperor Charles II. He visits the Court of England and meets Cardinal Wolsey and his wife Catherine, who are visiting England. The Cardinal's visit is to discuss the King's future. The Cardinal also meets the King of Portugal, Cardinal Wolsey. King Henry VIII visits the Court of England and meets Cardinal Wolsey and his wife Catherine of Aragon. King Henry VIII visits King Henry VIII and meets Cardinal Wolsey's daughter, the Cardinal. Cardinal Wolsey is a friend o    0.811619
# While Batman is distracted from the Joker's latest scheme, Batman and Robin follow him. Batman and Robin are trapped in a cave with the Joker, who has plans to use them for his own plans. The Joker escapes from the cave with the help of a mysterious masked man. Batman, Robin, and Batgirl must find the Joker before he uses his latest scheme.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              0.835589
# The Joker and Batgirl battle the Penguin and his henchmen, but not before the Penguin escapes with the Joker's latest creation, a new Arkham Asylum. Batman and Robin attempt to save the Joker and the Joker, but they're unable to stop him. Meanwhile, the Joker attempts to make his escape from Arkham Asylum and Batman and Robin are forced to watch from the sidelines.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     0.836344
# America's premiere sketch-comedy show returns for its second season LIVE from Studio 8H in New York City. This season, the cast includes Fred Armisen, Abby Elliott, Bill Hader, Andy Samberg, Bill Hader, Kenan Thompson, Kristen Wiig, featuring Vanessa Bayer, Jason Sudeikis, and Jay Pharoah. Check out these selected sketches and segments from each of this season's episodes, so you can make every night a Saturday Night.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                0.965442
# This Hooper Award Winning show is designed with the whole family in mind. The show's host, Jimmie Jackson, known as "Television's Singing Troubadour" is accompanied by the "Memory Lane Orchestra" as they perform nostalgic songs from the past on a musical stroll down "Memory Lane." The show also features "Television's Hollywood Hostess," Anita Coleman who shares the latest Hollywood gossip with her exciting celebrity guests. Moppet, J.P. Sloane is also occasionally featured as "Hollywood's Youngest Television Host."                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1.000000
# Name: plot_e, Length: 1608, dtype: float32

# %% [markdown]
# ### Grouped by genre

# %%
# Extract genre masks
genre_masks = {}
for genre, group in gen_df[valid_mask].groupby(by='genre'):
    gen_mask = gen_df[valid_mask].index.isin(group.index).tolist()
    train_mask = train_df['genres'].apply(lambda x: genre in x).tolist()
    genre_masks[genre] = np.asarray(gen_mask), np.asarray(train_mask)

# %%
# How similar are generated texts to training texts with respect to each genre?
print(pd.DataFrame({
    genre: np.nanmean(np.nanmax(jm[gen_mask, :, :][:, train_mask, :], axis=1), axis=0)
    for genre, (gen_mask, train_mask) in genre_masks.items() 
    if any(gen_mask) and any(train_mask)
}, index=['primary_j', 'secondary_j', 'plot_j', 'plot_e']).transpose().sort_values(by='primary_j', ascending=False))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: All-NaN slice encountered
#   after removing the cwd from sys.path.
#              primary_j  secondary_j    plot_j    plot_e
# drama         0.799991     0.387268  0.156703  0.648287
# romance       0.797843     0.352496  0.142429  0.637222
# thriller      0.580009     0.452093  0.152583  0.620722
# mystery       0.569366     0.445463  0.150931  0.616029
# sci-fi        0.566007     0.433373  0.143574  0.597198
# crime         0.529247     0.475820  0.146446  0.622159
# comedy        0.477796     0.386332  0.151382  0.592714
# adventure     0.460884     0.344050  0.140731  0.571900
# fantasy       0.454172     0.379963  0.140484  0.587274
# animation     0.433190     0.384416  0.142031  0.555749
# family        0.427470     0.428780  0.135224  0.562412
# horror        0.421122     0.262725  0.131128  0.558564
# news          0.405049     0.188721  0.121119  0.546652
# reality-tv    0.392912     0.311662  0.136342  0.531859
# action        0.382468     0.468658  0.150032  0.587946
# documentary   0.323565     0.282206  0.125557  0.533790
# talk-show     0.319719     0.174543  0.122453  0.530186
# game-show     0.286221     0.207060  0.115570  0.503529
# western       0.283012     0.396005  0.148059  0.560094
# music         0.240314     0.195948  0.116088  0.499141
# war           0.209490     0.256783  0.127997  0.518797
# history       0.193016     0.259960  0.122134  0.528661
# sport         0.192712     0.213854  0.119338  0.514791
# biography     0.163910     0.228394  0.116971  0.501582
# short         0.112508     0.192491  0.121675  0.474778
# musical       0.107799     0.195057  0.121959  0.486864
# adult         0.046176     0.128784  0.100481  0.388438

# %%
# Here is the true distribution the model was trained on
# If both distribution are similar, than the model established the link between genre and title properly
# It also shows which genres are the most expressive
pd.Series([genre for genres in train_df['genres'] for genre in genres]).value_counts()
# Out:
# drama          45890
# comedy         33870
# romance        19174
# family         15403
# crime          15120
# action         12376
# reality-tv     12336
# mystery        12025
# documentary    12020
# animation      11369
# adventure      10243
# thriller        8852
# sci-fi          8658
# fantasy         7103
# talk-show       5253
# news            3945
# music           2837
# western         2761
# history         2662
# horror          2571
# game-show       2045
# sport           1946
# war             1407
# biography       1385
# musical          595
# short            578
# adult             61
# dtype: int64

# %% [markdown]
# ### Grouped by temperature

# %%
# Extract temperature masks
temp_masks = {}
for temp, group in gen_df[valid_mask].groupby(by='temp'):
    temp_masks[temp] = gen_df[valid_mask].index.isin(group.index).tolist()

# %%
# How similar are generated texts to training texts with respect to temperature?
pd.DataFrame({
    temp: np.nanmean(np.nanmax(jm[gen_mask, :, :], axis=1), axis=0) 
    for temp, gen_mask in temp_masks.items() 
    if any(gen_mask)
}, index=['primary_j', 'secondary_j', 'plot_j', 'plot_e']).transpose().sort_values(by='primary_j', ascending=False).plot.bar()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: All-NaN slice encountered
#   after removing the cwd from sys.path.

# %% [markdown]
# ### Grouped by top_p

# %%
# Extract top_p masks
topp_masks = {}
for topp, group in gen_df[valid_mask].groupby(by='topp'):
    topp_masks[topp] = gen_df[valid_mask].index.isin(group.index).tolist()

# %%
# How similar are generated texts to training texts with respect to top_p?
pd.DataFrame({
    topp: np.nanmean(np.nanmax(jm[gen_mask, :, :], axis=1), axis=0) 
    for topp, gen_mask in topp_masks.items() 
    if any(gen_mask)
}, index=['primary_j', 'secondary_j', 'plot_j', 'plot_e']).transpose().sort_values(by='primary_j', ascending=False).plot.bar()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: All-NaN slice encountered
#   after removing the cwd from sys.path.

# %% [markdown]
# ### The most similar example

# %%
# Display the most similar example according to universal embeddings
gen_i, train_i = np.unravel_index(np.nanargmax(jm[:, :, 3]), jm.shape[:2])

# %%
jm[gen_i, train_i, :]
# Out:
# array([0.       ,       nan, 0.984375 , 1.0000001], dtype=float32)

# %%
print(gen_df[valid_mask].iloc[gen_i])
print(gen_df[valid_mask].iloc[gen_i]['plot'])
# Out:
# genre                                                talk-show
# title                  "What's My Line?" (1950) {(1953-11-15)}
# plot         This Hooper Award Winning show is designed wit...
# year                                                      1950
# episode                                                   None
# primary                                        What's My Line?
# secondary
# temp                                                       0.7
# topp                                                         0
# Name: 242, dtype: object
# This Hooper Award Winning show is designed with the whole family in mind. The show's host, Jimmie Jackson, known as "Television's Singing Troubadour" is accompanied by the "Memory Lane Orchestra" as they perform nostalgic songs from the past on a musical stroll down "Memory Lane." The show also features "Television's Hollywood Hostess," Anita Coleman who shares the latest Hollywood gossip with her exciting celebrity guests. Moppet, J.P. Sloane is also occasionally featured as "Hollywood's Youngest Television Host."

# %%
print(train_df.iloc[train_i])
print(train_df.iloc[train_i]['plot'])
# Out:
# title                      "Memory Lane" (1947) {(1950-07-28)}
# plot          This Hooper Award Winning show is designed wi...
# genres                                                 {music}
# year                                                      1947
# episode                                                   None
# primary                                            Memory Lane
# secondary
# Name: 57590, dtype: object
#  This Hooper Award Winning show is designed with the whole family in mind. The show's host, Jimmie Jackson, known as "Television's Singing Troubadour" is accompanied by the "Memory Lane Orchestra" as they perform nostalgic songs from the past on a musical stroll down "Memory Lane." The show also features "Television's Hollywood Hostess," Anita Coleman who shares the latest Hollywood gossip with her exciting celebrity guests. Moppet, J.P. Sloane is also occasionally featured as "Hollywood's Youngest Television Host."

# %% [markdown]
# ### The least similar examples

# %%
# Sort generated texts by the mean of all their similarities
sorted_i = np.argsort(np.nanmax(np.nanmean(jm, axis=2), axis=1))

# %%
print('\n'.join(gen_df[valid_mask].iloc[sorted_i[:5]]['plot'].tolist()))
# Out:
# Genes uit chom rect chin wedugenbed van Automar 96 (#8.2)}
# Forman cuppe grâme (#1.6)}
# ."Kentucky"," Genre / Ad entertainmentin 90 because no discrimination is allowed." reported Jerry Yanick if he stepped into muscle group sports equipment kitzkreet}
# Marcus kicks joy-ramps on Eb Partnerie Romica. features celebrity Julian Brods emotional know-allako So's brother Staunterolo. disaster strike projects (#1.63)}
# Prince Sebastian taught thementioned commits Trotsmann the typical Zen dialog over burial displeasure towards bronzed mud saying mimetic process and writings stacks is Harm all over getting too touch-y parts nostalgic old melodies liveed on just cause; 18th classovie Horst G Hoff just messed up 60 yearsylen Werner Willem bubble snake sea endlessveseries {Pickitto Paradise (#2.9)}

# %%
print(gen_df[valid_mask].iloc[sorted_i[0]])
print(gen_df[valid_mask].iloc[sorted_i[0]]['plot'])
# Out:
# genre                                                animation
# title        "Galvania 16" (1996) {Gullspinsev an om Deutsc...
# plot         Genes uit chom rect chin wedugenbed van Automa...
# year                                                      1996
# episode                                                    1.1
# primary                                            Galvania 16
# secondary                        Gullspinsev an om Deutschland
# temp                                                       1.3
# topp                                                         9
# Name: 1380, dtype: object
# Genes uit chom rect chin wedugenbed van Automar 96 (#8.2)}
