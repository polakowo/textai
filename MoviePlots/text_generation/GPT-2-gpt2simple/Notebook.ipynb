# %%
pip install gpt-2-simple
# Out:
# Collecting gpt-2-simple
#   Downloading https://files.pythonhosted.org/packages/75/2f/4b2d933decca7f79e3ae2eb3859e2b30bb1f572634d2c84f925d765e3b8e/gpt_2_simple-0.6.tar.gz
# Collecting regex
#   Downloading https://files.pythonhosted.org/packages/e3/8e/cbf2295643d7265e7883326fb4654e643bfc93b3a8a8274d8010a39d8804/regex-2019.11.1-cp36-cp36m-manylinux1_x86_64.whl (643kB)
#      |████████████████████████████████| 645kB 8.0MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from gpt-2-simple) (2.21.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from gpt-2-simple) (4.28.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from gpt-2-simple) (1.17.4)
# Collecting toposort
#   Downloading https://files.pythonhosted.org/packages/e9/8a/321cd8ea5f4a22a06e3ba30ef31ec33bea11a3443eeb1d89807640ee6ed4/toposort-1.5-py2.py3-none-any.whl
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->gpt-2-simple) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->gpt-2-simple) (2019.9.11)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->gpt-2-simple) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->gpt-2-simple) (2.8)
# Building wheels for collected packages: gpt-2-simple
#   Building wheel for gpt-2-simple (setup.py) ... done
#   Created wheel for gpt-2-simple: filename=gpt_2_simple-0.6-cp36-none-any.whl size=25388 sha256=9cc67b46cdb48c8a3ffa8436321bdd4887631e52b414d959efa844c08f5239e7
#   Stored in directory: /root/.cache/pip/wheels/cc/e7/21/4cb10bcf085ff791a08bbd03aa3fd860f6e730f37b5dbbea28
# Successfully built gpt-2-simple
# Installing collected packages: regex, toposort, gpt-2-simple
# Successfully installed gpt-2-simple-0.6 regex-2019.11.1 toposort-1.5

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %tensorflow_version 1.x

# %%
from tqdm import tqdm
import pandas as pd
import pickle
import math
import random
import os
from pathlib import Path
from collections import defaultdict
import shutil

import gpt_2_simple as gpt2
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
# Hyperparameters for training
MODEL_NAME = '124M'
SEED = 42
LR = 1e-4
BS = 1
GACCU_STEPS = 5
SAMPLE_STEPS = 1000
SAMPLE_LEN = 255
SAMPLE_NUM = 1
SAVE_STEPS = 1000
PRINT_STEPS = 100
TRAIN_STEPS = 40000

GENRES = ['Action', 'Adult', 'Adventure', 'Animation',
    'Biography', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Family',
    'Fantasy', 'Game-Show', 'History', 'Horror', 'Lifestyle', 'Music',
    'Musical', 'Mystery', 'News', 'Reality-TV', 'Romance', 'Sci-Fi',
    'Short', 'Sport', 'Talk-Show', 'Thriller', 'War', 'Western']

BOS_TOKEN = '<|startoftext|>'
EOS_TOKEN = '<|endoftext|>'
EOG_TOKEN = '|0|'
EOT_TOKEN = '|1|'

# %%
# Dumps
NUM_SAMPLES_PER_GENRE = 10
# The temperature is “creativity” and allows the network to more likely make suboptimal predictions
TEMPS = [0.7, 1, 1.3]
# https://github.com/minimaxir/gpt-2-simple/issues/51
TOP_PS = [0, 0.9]

# %%
# Only if re-finetuning
# !rm -rf "$CHECKPOINT_DIR"

# %%
# Remember to define the model dir in GDrive for persistence if using Colab
MODEL_DIR = Path("drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple")

# Prepared data
DATA_FILE = Path("drive/My Drive/Colab Notebooks/transformers/MoviePlots/data/data.pkl")

# Cache
# Our custom tokenizer with special tokens will be stored here
CACHE_DIR = MODEL_DIR/'cache'
CACHE_DIR.mkdir(exist_ok=True)
# Inputs will be stored here
TXT_FILE = CACHE_DIR/'data.txt'

# Checkpoints will be stored here
CHECKPOINT_DIR = MODEL_DIR/'checkpoint'
CHECKPOINT_DIR.mkdir(exist_ok=True)

# Dumps will be stored here
DUMPS_DIR = MODEL_DIR/"dumps"
DUMPS_DIR.mkdir(exist_ok=True)

# %%
# !ls "$MODEL_DIR"
# Out:
# cache  checkpoint  dumps  Notebook.ipynb

# %% [markdown]
# ## Prepare data

# %%
with open(DATA_FILE, 'rb') as handle:
    data = pickle.load(handle)

# %%
# Each plot has multiple genres
# But GPT-2 would learn more effectively if there was one-to-one relationship
# Two options: filter out plots with multiple genres, or duplicate them for each genre

def single_genre_augment(data):
    """For each plot with multiple genres, duplicate it for each genre."""
    augmented_data = []
    pbar = tqdm(total=len(GENRES)*len(data))
    for genre in GENRES:
        for d in data:
            if genre in d['genres']:
                single_genre_dict = dict(d)
                single_genre_dict['genre'] = genre.lower()
                augmented_data.append(single_genre_dict)
            pbar.update()
    pbar.close()
    return augmented_data

# %%
data = single_genre_augment(data)
# Out:
# 100%|██████████| 3281460/3281460 [00:02<00:00, 1240872.45it/s]

# %%
def encode_data(data):
    """For each dict in data, join information and generate a line."""
    lines = []
    for item in tqdm(data):
        lines.append(BOS_TOKEN + item['genre'] + EOG_TOKEN + item['title'] + EOT_TOKEN + item['plot'] + EOS_TOKEN)
    return lines

# %%
lines = encode_data(data)
# Out:
# 100%|██████████| 252490/252490 [00:00<00:00, 574982.70it/s]

# %%
pd.Series(lines)
# Out:
# 0         <|startoftext|>action|0|".hack//SIGN" (2002) {...
# 1         <|startoftext|>action|0|".hack//SIGN" (2002) {...
# 2         <|startoftext|>action|0|"10,000 Days" (2010)|1...
# 3         <|startoftext|>action|0|"10th Muse" (2012)|1| ...
# 4         <|startoftext|>action|0|"18 Wheels of Justice"...
#                                 ...
# 252485    <|startoftext|>western|0|"Zorro" (1990) {To Be...
# 252486    <|startoftext|>western|0|"Zorro" (1990) {Ultim...
# 252487    <|startoftext|>western|0|"Zorro" (1990) {Where...
# 252488    <|startoftext|>western|0|"Zorro" (1990) {Wicke...
# 252489    <|startoftext|>western|0|"Zorro" (1990) {Zorro...
# Length: 252490, dtype: object

# %%
def save_to_txt(lines):
    """Save lines into a TXT file."""

    with open(TXT_FILE, 'w', encoding='utf8', errors='ignore') as w:
        for line in tqdm(lines):
            w.write(line + "\n")

# %%
save_to_txt(lines)
# Out:
# 100%|██████████| 252490/252490 [00:00<00:00, 309643.60it/s]

# %% [markdown]
# ## Train model

# %%
# !nvidia-smi
# Out:
# Tue Nov 19 23:39:42 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 430.50       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P0    29W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
gpt2.download_gpt2(model_name=MODEL_NAME)
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 489Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 110Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 400Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:01, 267Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 345Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 147Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 154Mit/s]

# %%
sess = gpt2.start_tf_sess()
gpt2.finetune(sess,
              str(TXT_FILE),
              steps=TRAIN_STEPS,
              model_name=MODEL_NAME,
              batch_size=BS,
              learning_rate=LR,
              accumulate_gradients=GACCU_STEPS,
              sample_every=SAMPLE_STEPS,
              sample_length=SAMPLE_LEN,
              sample_num=SAMPLE_NUM,
              save_every=SAVE_STEPS,
              print_every=PRINT_STEPS,
              overwrite=True,
              checkpoint_dir=str(CHECKPOINT_DIR))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Loading checkpoint models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [03:41<00:00, 221.29s/it]
# dataset has 42951177 tokens
# Training...
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-0
# [100 | 130.99] loss=2.93 avg=2.93
# [200 | 255.39] loss=2.95 avg=2.94
# [300 | 379.86] loss=3.06 avg=2.98
# [400 | 504.24] loss=3.01 avg=2.99
# [500 | 628.56] loss=2.96 avg=2.98
# [600 | 752.89] loss=3.00 avg=2.99
# [700 | 877.28] loss=3.23 avg=3.02
# [800 | 1001.68] loss=3.34 avg=3.06
# [900 | 1125.96] loss=2.84 avg=3.04
# [1000 | 1250.23] loss=2.81 avg=3.01
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-1000
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# ======== SAMPLE 1 ========
# nered into a dangerous situation.<|endoftext|>
# <|startoftext|>adventure|0|"Mum's Up" (2013) {Mum's Up (#2.2)}|1| After her father's death, Sarah gets help from a new friend and the situation quickly becomes complicated, especially when she becomes a suspect in a police robbery. Sarah has to deal with her newfound feelings for her father, a criminal who thinks she is a killer and is being abused by his fellow criminals - especially a pregnant woman who thinks the police are following her. Meanwhile, Sarah's father is in jail awaiting trial for the murder of his wife.<|endoftext|>
# <|startoftext|>adventure|0|"Mum's Up" (2013) {Seal of Fortune (#1.13)}|1| As Sarah begins to be more suspicious of the situation in the family, there are more than a few people who believe she just needs time to reflect on the situation and realize what happened. Sarah is also concerned and unsure about what will happen next. Meanwhile, with the wedding planned, Sarah is concerned that someone will be coming to her house to take her away. There may be a new bride,
#
# [1100 | 1381.07] loss=2.94 avg=3.01
# [1200 | 1505.29] loss=2.67 avg=2.98
# [1300 | 1629.60] loss=3.20 avg=3.00
# [1400 | 1753.96] loss=2.33 avg=2.94
# [1500 | 1878.30] loss=3.02 avg=2.95
# [1600 | 2002.71] loss=2.69 avg=2.93
# [1700 | 2127.03] loss=2.88 avg=2.93
# [1800 | 2251.32] loss=2.84 avg=2.92
# [1900 | 2375.72] loss=2.74 avg=2.91
# [2000 | 2500.07] loss=2.82 avg=2.91
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-2000
# ======== SAMPLE 1 ========
#  wedding. In the process comes the truth.<|endoftext|>
# <|startoftext|>documentary|0|"Imaiah: An Interracial Perspective" (2012)|1| One-of-a-kind documentary series created for the first time on the first season of the first television channel of A&E's Adult Entertainment Television Channel (AETC) in August 2009 by the world renowned and Emmy Award-award-nominated actor and director, J.K. Simmons.<|endoftext|>
# <|startoftext|>documentary|0|"Irrational E.J." (1996)|1| 'Irrational E.J.' is a documentary series that follows a group of high school football prospects trying to make sense of their own pastimes and make sense of themselves.<|endoftext|>
# <|startoftext|>documentary|0|"If I Stay" (2014)|1| On the brink of the end of the show the kids have to make a decision about whether to come back to school. This is the season of 'Irrational E.J.'<|endoftext|>
# <|startoftext|>documentary|0
#
# [2100 | 2630.58] loss=2.76 avg=2.90
# [2200 | 2754.98] loss=2.86 avg=2.90
# [2300 | 2879.35] loss=2.55 avg=2.88
# [2400 | 3003.75] loss=2.70 avg=2.87
# [2500 | 3128.03] loss=2.46 avg=2.86
# [2600 | 3252.34] loss=2.99 avg=2.86
# [2700 | 3376.78] loss=2.69 avg=2.85
# [2800 | 3501.27] loss=2.77 avg=2.85
# [2900 | 3625.71] loss=2.82 avg=2.85
# [3000 | 3750.04] loss=2.72 avg=2.84
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-3000
# ======== SAMPLE 1 ========
#  a woman named Kate, who has had a relationship with and killed one of the characters in the show. The plot line is one of revenge for the death of a fellow passenger. So the two women, who also happen to be the people who used a weapon in the incident, work towards their long-awaited escape from San Francisco.<|endoftext|>
# <|startoftext|>drama|0|"The People" (1992) {Sins of the Father (#3.15)}|1| The show follows five young men that go through a difficult adolescence in the aftermath of their parents' death, with the help of their older siblings, friends, their parents, mentors and a group of friends who are just beginning their new lives.<|endoftext|>
# <|startoftext|>drama|0|"The People" (1992) {This is My Girl (#4.12)}|1| The show follows three college women who become involved with their boyfriends when, in college, he falls for another girl, whose mother is pregnant. While their relationships progress, the girls have a hard time figuring out just how much she wants to be with them.<|endoftext|>
# <|start
#
# [3100 | 3879.64] loss=2.77 avg=2.84
# [3200 | 4003.81] loss=2.89 avg=2.84
# [3300 | 4128.00] loss=2.54 avg=2.83
# [3400 | 4252.14] loss=2.69 avg=2.83
# [3500 | 4376.33] loss=2.72 avg=2.82
# [3600 | 4500.42] loss=2.37 avg=2.81
# [3700 | 4624.62] loss=2.82 avg=2.81
# [3800 | 4748.81] loss=2.63 avg=2.80
# [3900 | 4872.94] loss=2.86 avg=2.81
# [4000 | 4997.13] loss=2.95 avg=2.81
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-4000
# ======== SAMPLE 1 ========
#  to get the job done and he goes through great pains to be himself again. He is accepted into a good school. He gets a job at The Hump and then he gets promoted to principal.<|endoftext|>
# <|startoftext|>drama|0|"One Piece" (2003) {The Great Mangere in the Woods (#6.11)}|1| It is a dangerous time for the Straw Hat Pirates as all of the pirate ships have been sunk by pirates. So everyone starts heading south to the north to get them out of the way, and while on their way it falls on the beach into the woods. The Straw Hat Pirates are unable to make it for the woods and start to take their ships out. The battle comes down to the last stand that the Straw Hat Pirates have made. And it is a very difficult battle in front of them. With their power dwindling as this new threat spreads to the other side, they cannot be stopped.<|endoftext|>
# <|startoftext|>drama|0|"One Piece" (2003) {The Holy Ghost of Mangere Mountain (#7.16)}|1| On Mangere Mountain, where everyone fears them worst
#
# [4100 | 5127.88] loss=2.54 avg=2.80
# [4200 | 5252.11] loss=2.90 avg=2.80
# [4300 | 5376.18] loss=2.76 avg=2.80
# [4400 | 5500.47] loss=2.50 avg=2.79
# [4500 | 5624.66] loss=2.21 avg=2.78
# [4600 | 5748.87] loss=2.67 avg=2.78
# [4700 | 5873.17] loss=2.58 avg=2.77
# [4800 | 5997.44] loss=2.57 avg=2.77
# [4900 | 6121.81] loss=2.70 avg=2.76
# [5000 | 6246.17] loss=2.53 avg=2.76
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-5000
# ======== SAMPLE 1 ========
#  his family. The situation with Tom and Kelly seems to be changing as the wedding season approaches. It's like being in love with a married woman's family, so if Tom is upset about his feelings, Kelly is. But that's not the case when it comes to their wedding plans.<|endoftext|>
# <|startoftext|>reality-tv|0|"Tatak" (2009) {Family Guy (#1.2)}|1| As the wedding season winds down, there's no shortage of work looking for the family: the bride's children. That's no problem for the matriarch, as she makes a point of describing her three children to the press. And she's done so successfully for her mother, who's just married the young man she thinks is her daughter and is pregnant.<|endoftext|>
# <|startoftext|>reality-tv|0|"Tatak" (2009) {Hotel Room/Family (#1.16)}|1| Tom is still reeling from losing the last time he went to the hotel room, after Tom and Kelly's attempt to come up with a compromise while he waited for the elevator, and the stress of the first hour. Kelly
#
# [5100 | 6376.03] loss=3.14 avg=2.77
# [5200 | 6500.61] loss=2.64 avg=2.76
# [5300 | 6625.04] loss=2.63 avg=2.76
# [5400 | 6749.46] loss=2.78 avg=2.76
# [5500 | 6873.80] loss=2.74 avg=2.76
# [5600 | 6998.06] loss=2.66 avg=2.76
# [5700 | 7122.28] loss=2.48 avg=2.75
# [5800 | 7246.50] loss=2.36 avg=2.74
# [5900 | 7370.78] loss=2.70 avg=2.74
# [6000 | 7495.04] loss=2.51 avg=2.74
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-6000
# ======== SAMPLE 1 ========
#  until she decides to stay in the hospital and work with Dr. Baker. A heart-attack and a seizure during his operation leave him unconscious. They find his sister, who is still in an armchair, and they decide to call him to come and see her. He's an ER patient who feels like he's being taken advantage of. Abby isn't sure about her relationship with Jake. At the same time, Maggie, with Matt's help, struggles to have sex with her new boyfriend. Matt and Maggie are having sex and Matt is furious that he's having sex with Maggie with him. Maggie and Jake then share a passionate kiss, but Maggie isn't sure they are meant to be together.<|endoftext|>
# <|startoftext|>drama|0|"Texas" (1980) {(#1.6448)}|1| Bill returns home from the hospital with Bill, still in a tizzy that he can't get a good night's sleep. His condition has improved a lot, he feels better, and his doctor has sent him a check for possible colon cancer. Bill finally asks Matt to have dinner at the hospital for him, but Matt takes it so seriously that he's going to have sex with Bill. At
#
# [6100 | 7626.05] loss=2.48 avg=2.73
# [6200 | 7750.37] loss=2.42 avg=2.72
# [6300 | 7874.67] loss=2.56 avg=2.72
# [6400 | 7999.26] loss=2.46 avg=2.72
# [6500 | 8123.85] loss=2.57 avg=2.71
# [6600 | 8248.35] loss=2.58 avg=2.71
# [6700 | 8372.94] loss=2.23 avg=2.70
# [6800 | 8497.43] loss=2.39 avg=2.69
# [6900 | 8621.98] loss=2.76 avg=2.70
# [7000 | 8746.57] loss=2.54 avg=2.69
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-7000
# ======== SAMPLE 1 ========
#  fabrics in the neighborhood of the apartment above the office. What will she get when she puts on her shoes and leaves her apartment?<|endoftext|>
# <|startoftext|>comedy|0|"Wes" (1995)|1| Eclectic, fun and sometimes hilarious. The whole thing is centered around the life of Wes Anderson and his many, many fans. Wes is an avid comic book collector, a hard-drinking and unpredictable, even bumbling writer who keeps his wife Suzie occupied all the time. Wes works as a comic book artist and occasionally writes material for a magazine about science fiction and fantasy, but he is also often a character witness at the very worst of crime. In addition, they have a very different home environment than most people; a small city in the middle of the Atlantic. Wes and his friends will battle the adventures of Wes Anderson; the best and the worst, and whether Wes or his brother Sam Wes has to stay somewhere in the middle or not, he always seems to be able to escape the big and small things. The web series is a satire of a small city society with a rich man and a pretty girl to keep the world running smoothly. Wes and his friends often work
#
# [7100 | 8876.60] loss=2.60 avg=2.69
# [7200 | 9001.24] loss=2.45 avg=2.69
# [7300 | 9126.23] loss=2.34 avg=2.68
# [7400 | 9251.17] loss=2.39 avg=2.67
# [7500 | 9376.13] loss=2.68 avg=2.67
# [7600 | 9501.15] loss=2.80 avg=2.68
# [7700 | 9626.08] loss=2.47 avg=2.67
# [7800 | 9751.07] loss=2.61 avg=2.67
# [7900 | 9876.08] loss=2.46 avg=2.67
# [8000 | 10001.03] loss=2.79 avg=2.67
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-8000
# ======== SAMPLE 1 ========
#  appearance of an old man. He goes into shock on the way.<|endoftext|>
# <|startoftext|>sci-fi|0|"Batman" (1966) {The Man Who Knew Too Much (#2.41)}|1| Batman and Robin try to track down the man who was responsible for the death of a young woman. When they locate his daughter, she is still alive and they learn that he is a wealthy businessman. Batman and Robin find a man dressed in black and he tries to locate the man. Meanwhile, Bruce Wayne's ex-wife Penny and son Wally and niece Janbel have a brief conversation with Bruce Wayne about the accident.<|endoftext|>
# <|startoftext|>sci-fi|0|"Batman" (1966) {The Phantom Menace (#2.36)}|1| Bruce Wayne's former associate, Madame Uffina, arrives in Gotham and entrusts Batman. Now she is threatening Wayne Manor and Batman and Robin will have to find his old friend, Dr. Drakken. Once Batman and Robin, she reveals to them that Madame Uffina is back in Gotham. When Batman arrives, she plans to kidnap Princess Diana, Maxwell and her
#
# [8100 | 10131.31] loss=2.75 avg=2.67
# [8200 | 10256.27] loss=2.44 avg=2.67
# [8300 | 10381.18] loss=2.61 avg=2.67
# [8400 | 10506.25] loss=2.40 avg=2.66
# [8500 | 10631.22] loss=2.55 avg=2.66
# [8600 | 10756.19] loss=2.24 avg=2.65
# [8700 | 10881.13] loss=2.28 avg=2.65
# [8800 | 11006.13] loss=2.02 avg=2.64
# [8900 | 11131.09] loss=2.44 avg=2.63
# [9000 | 11256.05] loss=2.02 avg=2.62
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-9000
# ======== SAMPLE 1 ========
#  of the party. This episode aired on Sunday, February 9, 2007 at 7:00 p.m. EST on Discovery. In the series premiere viewers watched as the cast and crew of the episode - as well as some of the cast and crew - spoke about their experiences, the new episodes they have been receiving, what they hope viewers will do to support their favourite cast members.<|endoftext|>
# <|startoftext|>documentary|0|"The Discovery Channel Presents" (2012) {(#1.1)}|1| Discovery Channel explores the search for life on Mars and Mars Exploration in the search for life. We talk with scientists, engineers, archaeologists, and others about the latest research that is pushing NASA ever closer to Mars. We take an in-depth look at an effort to send robotic missions into Mars in the search for life. We answer the scientific questions, news-makers and entrepreneurs who are investing in space.<|endoftext|>
# <|startoftext|>documentary|0|"The Discovery Channel Presents" (2012) {(#1.11)}|1| In the series premiere, Discovery explores why scientists are studying the origin of life on the Red Planet. We hear
#
# [9100 | 11387.47] loss=2.59 avg=2.62
# [9200 | 11512.08] loss=2.13 avg=2.61
# [9300 | 11636.59] loss=2.35 avg=2.61
# [9400 | 11761.07] loss=2.52 avg=2.61
# [9500 | 11886.00] loss=2.65 avg=2.61
# [9600 | 12011.05] loss=2.08 avg=2.60
# [9700 | 12135.99] loss=1.97 avg=2.59
# [9800 | 12261.01] loss=2.15 avg=2.58
# [9900 | 12386.02] loss=2.59 avg=2.58
# [10000 | 12510.97] loss=2.39 avg=2.58
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-10000
# ======== SAMPLE 1 ========
#  a big surprise awaits for everyone, when it turns out the biggest surprise is on the doorstep in San Fran.<|endoftext|>
# <|startoftext|>reality-tv|0|"Come Dine with Me Canada" (2010) {The Final Table (#1.12)}|1| A Final Four, where each of the finalists gets a chance to have their cake & cheese pie served in style while they were at home with their family and friends, will the winner be crowned the Finalist of Canada's Next Great White Challenge? The Final Four are: the chef: the two finalists will be given two delicious cakes & cheeses at dinner - the winner going through the menu for his/her final dinner, with all participants going home in the case of the Final Four; The finalist and the person who is eliminated from the competition, the one who gets the grand prize<|endoftext|>
# <|startoftext|>reality-tv|0|"Come Dine with Me Canada" (2010) {The Favorite Feast (#3.7)}|1| The Final Four: The chef: The two finalists will be given two delicious cakes & cheeses at dinner - the winner going through the menus for
#
# [10100 | 12641.30] loss=2.78 avg=2.58
# [10200 | 12766.31] loss=2.01 avg=2.57
# [10300 | 12891.32] loss=2.26 avg=2.57
# [10400 | 13016.35] loss=2.23 avg=2.56
# [10500 | 13141.38] loss=2.20 avg=2.56
# [10600 | 13266.49] loss=2.31 avg=2.55
# [10700 | 13391.51] loss=2.40 avg=2.55
# [10800 | 13516.49] loss=2.47 avg=2.55
# [10900 | 13641.51] loss=2.42 avg=2.55
# [11000 | 13766.51] loss=2.38 avg=2.55
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-11000
# ======== SAMPLE 1 ========
#  her, but he refuses to consider going back to school. Danny asks to take a paternity test and is told he's too young to pass up the chance to have a father figure his own way. A call to the police indicates a witness may have seen Quinn in the car and it's assumed she's dead; another girl has since died, having been raped by Quinn, who now has a new identity as a prostitute prostitute- even though Danny can't find any evidence that either of the two existed. Quinn has his doubts about the identity of his dead wife as well. Quinn, who now has custody over her, continues his attacks on a number of children. In the middle of the night, Danny and Quinn break in a motel room and begin to sleep together; the next day, he invites her to a dinner and she happily accepts. While they sleep, Quinn has a call from Quinn's ex-boyfriend asking her to return Quinn's phone number. When Quinn arrives at his house in the middle of the night, she calls the police demanding he return her phone number but no one in the family knows he committed suicide. Quinn has just over a year to live and it's still very close to the end.<|endoftext|>
# <|startof
#
# [11100 | 13896.86] loss=2.03 avg=2.54
# [11200 | 14021.84] loss=2.60 avg=2.54
# [11300 | 14146.80] loss=2.63 avg=2.54
# [11400 | 14271.77] loss=2.44 avg=2.54
# [11500 | 14396.67] loss=2.48 avg=2.54
# [11600 | 14521.56] loss=2.28 avg=2.53
# [11700 | 14646.35] loss=2.40 avg=2.53
# [11800 | 14771.10] loss=2.41 avg=2.53
# [11900 | 14895.97] loss=2.38 avg=2.53
# [12000 | 15020.77] loss=2.22 avg=2.52
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-12000
# ======== SAMPLE 1 ========
# . While they talk, a thief breaks into their garage in an attempt to steal stuff. Unfortunately for them, they're the wrong party: a "friend" already has a grudge against a major department store. The robbers are spotted by the store's security chief and are being pursued by security officers who have been given extra training in the use of force. The robbers have taken the evidence which must be kept away from patrons. The thief, however, can't be held indefinitely and so has to be put back in, not without a fight. The thieves are only seen in silhouette of the mall's security guard's uniform (the one in the blue visor). The last alarm, when the thieves were seen leaving the garage, is an earlier alarm, which gives the robbers time to leave the mall and escape. Before they can escape their pursuers, the store closes and the criminals close in on the mall's security chief. When he discovers who they are, he decides to dole out a new punishment to the robbers.<|endoftext|>
# <|startoftext|>mystery|0|"No Ordinary Family" (2010) {Candy Girl Kills Someone (#3.8)}|1| A young teen is a free spirited
#
# [12100 | 15152.33] loss=2.33 avg=2.52
# [12200 | 15277.24] loss=2.34 avg=2.52
# [12300 | 15402.09] loss=2.49 avg=2.52
# [12400 | 15527.00] loss=2.37 avg=2.52
# [12500 | 15651.93] loss=2.41 avg=2.51
# [12600 | 15776.82] loss=2.41 avg=2.51
# [12700 | 15901.74] loss=2.48 avg=2.51
# [12800 | 16026.70] loss=2.29 avg=2.51
# [12900 | 16151.60] loss=2.09 avg=2.50
# [13000 | 16276.54] loss=2.15 avg=2.50
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-13000
# ======== SAMPLE 1 ========
#  the police in a plot involving both Mac and Daphne.<|endoftext|>
# <|startoftext|>romance|0|"MacMaster" (1986) {The Girl in the Blue Fire (#1.3)}|1| Mac and Daphne's school's basketball team gets invited to a concert. In it, Mac and Daphne meet the girl of their dreams, a tennis star, whom they try to kiss but fail. Eventually they kiss again...and become both friends. The reason for this is explained later when Mac wakes up in the hospital: there he meet a girl just like him, who just finished her high school football career, and whom he likes to flirt. It is the girl who left home to spend the summer with his dad, whom he loves, and who he wants to date but can't quite seem to do it. After being dumped by her ex Mark, she wants him to do it again. Only that leaves Mac in a dilemma and he and the rest of the family have to get rid of such a persistent girl, who seems ready to put someone else around.<|endoftext|>
# <|startoftext|>romance|0|"MacMaster" (1986
#
# [13100 | 16406.96] loss=2.29 avg=2.50
# [13200 | 16531.82] loss=2.14 avg=2.49
# [13300 | 16656.86] loss=2.65 avg=2.49
# [13400 | 16781.81] loss=2.48 avg=2.49
# [13500 | 16906.75] loss=2.24 avg=2.49
# [13600 | 17031.70] loss=2.21 avg=2.49
# [13700 | 17156.64] loss=2.15 avg=2.48
# [13800 | 17281.82] loss=2.29 avg=2.48
# [13900 | 17406.98] loss=2.37 avg=2.48
# [14000 | 17531.84] loss=2.52 avg=2.48
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-14000
# ======== SAMPLE 1 ========
#  with a little overdoing it. Their love story is born.<|endoftext|>
# <|startoftext|>comedy|0|"Girlfriends Anonymous" (2010) {(#1.3)}|1| A bit of a misfire in the dating department leads to a disastrous affair with a girl from Girlfriends Anonymous, and a new friend named Lisa. An effort is made to patch up things after a long day of dating with a new girlfriend named Tina. Once back with Tina they decide to go for a quick one-liner while a new boyfriend returns with an agenda that could derail their plans for the day. Will the Girlfriends Anonymous be able to put a stop to the new girlfriend's bad ideas?<|endoftext|>
# <|startoftext|>comedy|0|"Girlfriends Anonymous" (2010) {(#1.5)}|1| Girlfriends Anonymous tries to find the perfect girlfriend for their new boyfriend who they call "Lenny". Lisa gets caught between Lisa and Tina. Lisa will she set a date for dinner before Lisa meets Lisa's friends so that Tina can meet Tina's new boyfriend. Tina will need to settle this in a quiet way
#
# [14100 | 17662.12] loss=2.45 avg=2.48
# [14200 | 17787.14] loss=2.05 avg=2.47
# [14300 | 17911.99] loss=1.68 avg=2.46
# [14400 | 18036.58] loss=1.96 avg=2.46
# [14500 | 18161.43] loss=2.33 avg=2.45
# [14600 | 18286.36] loss=1.80 avg=2.45
# [14700 | 18411.30] loss=2.32 avg=2.44
# [14800 | 18536.30] loss=2.13 avg=2.44
# [14900 | 18661.24] loss=2.21 avg=2.44
# [15000 | 18786.24] loss=1.63 avg=2.43
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-15000
# ======== SAMPLE 1 ========
#  Pikachu, Chobani and Rurichi have a row in the hallway, where Takarotto chases after them. Takarotto, who is unconscious, hears a loud crash and runs upstairs to a terrified Chobani. They try to hide but can't move without knocking out the intruder. Takarotto is found by his friends, his mother and the mysterious Rurichi. He is very brave and runs to the roof where Chobani is struggling to escape. He hears the wind and races down the steps as the mysterious Rurichi watches. His friends gather to watch the mysterious Rurichi from afar. The sounds of their strange creatures and the strange sounds of the catatonic Rurichi is too eerie for Takarotto, and he passes out. The mysterious Rurichi tries to scare Takarotto by telling him it is his father and chases him to an abandoned house in the forest. He finally makes it to a cabin, but it becomes violent and violent and Rurichi loses control and is pushed into the wall. In this state the Rurichi is unable to fight and falls into the water. Takarotto tries to take back and abandon the mysterious Rurichi but
#
# [15100 | 18917.95] loss=2.59 avg=2.43
# [15200 | 19042.91] loss=2.32 avg=2.43
# [15300 | 19167.80] loss=2.30 avg=2.43
# [15400 | 19292.66] loss=2.34 avg=2.42
# [15500 | 19417.58] loss=1.73 avg=2.42
# [15600 | 19542.49] loss=2.03 avg=2.41
# [15700 | 19667.34] loss=1.53 avg=2.40
# [15800 | 19792.23] loss=1.71 avg=2.39
# [15900 | 19917.22] loss=2.23 avg=2.39
# [16000 | 20042.16] loss=2.17 avg=2.39
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-16000
# ======== SAMPLE 1 ========
# 2002) {(#1.5)}|1| Gwen is shocked to see the new name on her birth certificate. Mavis gives a video to Tim, who says it can read him as a young man. Mavis' sister, Dawn, comes over to Aidensfield to help her out but gets suspicious of John's motives. David's nephew Joe shows up demanding money and the doctor is perturbed that he has nothing to offer him, unlike Downton, whose first patient, Ruth, is still in hospital. Ruth has no idea who she is and Aidensfield's medical staff and hospital staff don't think she might have the right disease. Mavis and Tim are reunited. Roddy the surgeon explains about the reasons for the names and suggests that they're a case of genetic incompatibility but Tim refuses that and he collapses whilst Downton and Joe do their best to take him in. Ruth tells John that she may have a mild form of cancer but his questions suggest she has a tumour. Dawn's father visits Aidensfield having fallen off of an airplane. He gives David a letter and says that there is nothing he can do but is still annoyed at how things turn out. Pregnant Amy is still waiting for her operation so
#
# [16100 | 20172.66] loss=1.76 avg=2.38
# [16200 | 20297.74] loss=2.51 avg=2.38
# [16300 | 20422.76] loss=1.49 avg=2.37
# [16400 | 20547.77] loss=2.14 avg=2.37
# [16500 | 20672.78] loss=1.94 avg=2.36
# [16600 | 20797.85] loss=2.18 avg=2.36
# [16700 | 20922.79] loss=2.12 avg=2.36
# [16800 | 21047.74] loss=1.91 avg=2.35
# [16900 | 21172.65] loss=2.42 avg=2.35
# [17000 | 21297.57] loss=1.62 avg=2.34
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-17000
# ======== SAMPLE 1 ========
# 1| Dr. Bill Lee wants to get his daughter pregnant but the baby is not stable. Dr. Bill wants to make sure the baby is safe - even if it means giving it up to Dr. D'Estaing. Aiden finds a baby he was not expecting, so Bill wants information. And after a visit from a cousin - his first pregnant wife - Dr. D'Estaing wants to know what the baby's life will be like. Unfortunately, his cousin is not very hospitable to a pregnancy.<|endoftext|>
# <|startoftext|>comedy|0|"The X Files" (1993) {Family Planning (#7.11)}|1| It's Dr. Doris D after all that crazy time with her unborn child who takes control of her and scares her out of her head. She tries to make her way across the country trying to have the baby before the big day. Meanwhile, Agent Johnson has to deal with the case of a young woman who has a strange rash. She doesn't remember it very well, but it happened.<|endoftext|>
# <|startoftext|>comedy|0|"The X Files" (1993) {Father Knows
#
# [17100 | 21427.92] loss=1.99 avg=2.34
# [17200 | 21552.93] loss=1.56 avg=2.33
# [17300 | 21678.00] loss=1.80 avg=2.32
# [17400 | 21803.00] loss=2.44 avg=2.32
# [17500 | 21928.02] loss=2.00 avg=2.32
# [17600 | 22053.05] loss=1.79 avg=2.31
# [17700 | 22178.05] loss=2.33 avg=2.31
# [17800 | 22303.03] loss=2.28 avg=2.31
# [17900 | 22428.04] loss=2.92 avg=2.32
# [18000 | 22553.06] loss=2.34 avg=2.32
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-18000
# ======== SAMPLE 1 ========
#  Son, the kids go on a picnic with them. Also, Peter's relationship with Charlotte is becoming more strained.<|endoftext|>
# <|startoftext|>comedy|0|"The Love Boat" (1977) {The Princess and the Pig/The Fugitive/The Man Who Never Was/The Bionic Child/The Scandal (#3.8)}|1| A cruise ship's maintenance is complicated when a super hero with a conscience comes to investigate Captain Brackenreid, the Captain's daughter, for his exorbitant wages, and to prove her father's innocence. Also, a female passenger suffers an injury while performing a dangerous chair lift on board a ship traveling from Antigua to the Philippines.<|endoftext|>
# <|startoftext|>comedy|0|"The Love Boat" (1977) {The Rumor Ship Incident/The Two Maytors/The Cop (#1.18)}|1| On a cruise ship, the crew, plus Captain Brackenreid's daughter Alice, goes on a cruise to Jamaica, where Captain Brackenreid is a doctor. She gets lost, but the doctor tells her she can't go. Captain
#
# [18100 | 22684.69] loss=2.02 avg=2.32
# [18200 | 22809.57] loss=2.27 avg=2.32
# [18300 | 22934.55] loss=1.67 avg=2.31
# [18400 | 23059.49] loss=2.40 avg=2.31
# [18500 | 23184.39] loss=2.01 avg=2.31
# [18600 | 23309.29] loss=2.24 avg=2.31
# [18700 | 23434.18] loss=2.03 avg=2.30
# [18800 | 23559.21] loss=1.93 avg=2.30
# [18900 | 23684.27] loss=1.57 avg=2.29
# [19000 | 23809.28] loss=1.98 avg=2.29
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-19000
# ======== SAMPLE 1 ========
# ) {The Dark Queen's Return (#2.11)}|1| The return of the Dark Queen is not quite as expected. As the days progress, the forces of the Dark Lord's Kingdom will find themselves embroiled in a battle for control. Will the Kingdom's most powerful member be able to fend them off? And will Jules be able to pull off the ultimate betrayal to get her way?<|endoftext|>
# <|startoftext|>family|0|"Ivor the Engine" (1979) {The First Day Of The Gun (#1.9)}|1| A small village is suffering from an epidemic of gun murders, due to the way smugglers transport money. The smugglers believe this will result in the village being "Gun Free" until a visit from a new arrival breaks the cycle.<|endoftext|>
# <|startoftext|>family|0|"Ivor the Engine" (1979) {The Last Journey Beyond (#1.5)}|1| The engine of the M25 becomes trapped in its "Last Journey" mission, in the Arctic, when its escorts are cut off after being "gunned down".<|endoftext|>
# <|startoftext
#
# [19100 | 23939.63] loss=2.03 avg=2.28
# [19200 | 24064.57] loss=2.07 avg=2.28
# [19300 | 24189.57] loss=2.20 avg=2.28
# [19400 | 24314.58] loss=2.02 avg=2.28
# [19500 | 24439.54] loss=1.59 avg=2.27
# [19600 | 24564.50] loss=1.78 avg=2.26
# [19700 | 24689.51] loss=1.98 avg=2.26
# [19800 | 24814.47] loss=2.29 avg=2.26
# [19900 | 24939.41] loss=2.03 avg=2.26
# [20000 | 25064.38] loss=2.29 avg=2.26
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-20000
# ======== SAMPLE 1 ========
#  for him. Franky tells Bram they can't say Franky didn't want to see him any time soon, because he might never again tell Julia. Sam wants to send the money he received from his father. But when she's in Ter Smissen, she's too drunk to ride. When Jens has her back after a few hours, they have a nice discussion and are very happy with it. Julia forgot Eddy made an exchange. Waldek still hasn't said anything, but Tim doesn't know anything yet. When Waldek tells about the money he found on Julia's luggage, he and Tim believe it's from the bank, so he's a bit tipsy about that. Waldek knows what he has to do and makes a decision. Waldek has to make a decision. Franky asks Luc what they should do. He says this is to get Rosa as a friend, but Rosa gets very cold feet. It's just not right. Nancy tells Femke about the photo's she got of Eddy that were taken by Simonne. Geert is glad she asked him to help her on Lowie. Sam wants to help and Geert agrees, but he only can talk to him. When Geert has to send Sam an envelope with
#
# [20100 | 25194.63] loss=1.83 avg=2.25
# [20200 | 25319.55] loss=2.30 avg=2.25
# [20300 | 25444.48] loss=2.07 avg=2.25
# [20400 | 25569.40] loss=1.71 avg=2.24
# [20500 | 25694.34] loss=1.93 avg=2.24
# [20600 | 25819.30] loss=1.42 avg=2.23
# [20700 | 25944.26] loss=1.71 avg=2.23
# [20800 | 26069.23] loss=2.42 avg=2.23
# [20900 | 26194.10] loss=1.94 avg=2.22
# [21000 | 26319.05] loss=1.77 avg=2.22
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-21000
# ======== SAMPLE 1 ========
#  her first husband and, before her death, her mother, who became an obstetrician. But she and her two children died. She was a poor widow and had had little choice but to go to marriage. This made her life miserable once again. But she finally made am and married a man who became quite the father for her. She was at forty years old and a great care was taken to ensure that she got right. But this became the charm and they called her mother. And now she is gone. She had been married for four years, had two children including daughter Anya and a son who is very rare in the population. In the house she died, but she and her husband are very busy in life and want to stay. They have given her a new job, and she has very happy memories of everything there is to do with her work. But she also is still a very young child.<|endoftext|>
# <|startoftext|>comedy|0|"Prófugos" (2009) {Lucha Libre (#1.3)}|1| An unexpected visit from the daughter of one of the students of the school, Dávila and Mariela, who is also the new head
#
# [21100 | 26450.34] loss=2.17 avg=2.22
# [21200 | 26575.20] loss=2.44 avg=2.22
# [21300 | 26700.02] loss=2.08 avg=2.22
# [21400 | 26824.91] loss=1.47 avg=2.21
# [21500 | 26949.81] loss=1.94 avg=2.21
# [21600 | 27074.70] loss=1.73 avg=2.20
# [21700 | 27199.55] loss=1.83 avg=2.20
# [21800 | 27324.49] loss=2.01 avg=2.20
# [21900 | 27449.49] loss=2.35 avg=2.20
# [22000 | 27574.43] loss=1.98 avg=2.20
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-22000
# ======== SAMPLE 1 ========
# 18) with the help of T.K. and the team of interns at the mall's hardware store. Also, a young boy is brought in with spinal meningitis.<|endoftext|>
# <|startoftext|>drama|0|"Banshee" (2013) {Siege (#2.12)}|1| During the Zombie Apocalypse, the USA has an agreement with the aliens to defend itself against invasion. So the gang travels to the border of Managua and try to infiltrate a building that is protected by zombies. They discover the owner of the building, Francis, dead in the infirmary and with a simple notification, they go in. Francis told them via a security alert that something is wrong. So they go in and they are surprised to see the zombies. And they also see a man that looks like Francis and that is the zombie, that is what they later call a zombie killer. They try to disarm the man and Francis tells them the man was one of the last remaining soldiers of the colony. That man, Jarvis, was the sole survivor of some of the colony's sexual assaults in the 200 years before the war. And he warns them to be very careful in who they approach. But they
#
# [22100 | 27704.72] loss=1.77 avg=2.19
# [22200 | 27829.68] loss=1.93 avg=2.19
# [22300 | 27954.59] loss=1.85 avg=2.18
# [22400 | 28079.50] loss=2.23 avg=2.18
# [22500 | 28204.41] loss=1.88 avg=2.18
# [22600 | 28329.26] loss=2.31 avg=2.18
# [22700 | 28454.28] loss=2.47 avg=2.19
# [22800 | 28579.23] loss=2.44 avg=2.19
# [22900 | 28704.14] loss=1.84 avg=2.19
# [23000 | 28829.10] loss=1.69 avg=2.18
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-23000
# ======== SAMPLE 1 ========
#  (2007) {The Big Head: Part 1 - All That's Left Inside (#1.21)}|1| Now in a world where they all have a taste, the Bishops have been forced to work together as a team, a goal which is maintained despite a few mishaps. Among these are the two captains that the Bishops have had the most trouble in working with the most difficult and emotional of issues, a couple of them, in one case, are now out of the role of Bishops altogether. One who has begun to take criticism on and attack their abilities as a team is the Captain's brother, Alex, who is the chief of operations of the new Bishops and has not had the courage to do so in quite some time. When the latter has to be killed in a fight with a monster in a park, the issue of how to work within his brother's broken heart returns to the issue of how to treat his pregnant wife, Sarah, and Alex's new partner, Lachlan - who he had hoped to be an ally to be a supportive disciplinarian - becomes more and more one of the challenges for the team.<|endoftext|>
# <|startoftext|>adventure|0|"Bishops
#
# [23100 | 28959.31] loss=2.03 avg=2.18
# [23200 | 29084.23] loss=1.41 avg=2.17
# [23300 | 29209.17] loss=1.48 avg=2.16
# [23400 | 29334.08] loss=1.96 avg=2.16
# [23500 | 29459.02] loss=1.74 avg=2.16
# [23600 | 29584.01] loss=1.44 avg=2.15
# [23700 | 29708.98] loss=1.95 avg=2.15
# [23800 | 29833.92] loss=1.97 avg=2.14
# [23900 | 29958.82] loss=2.02 avg=2.14
# [24000 | 30083.80] loss=2.01 avg=2.14
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-24000
# ======== SAMPLE 1 ========
# |00|00|01|0|0|00|0|00#017d
# <|0|0|0|00#008 POD: Daybreak Pregnant Leete Kibriou' 's birthday went surprisingly well. Yet despite her initial excitement, Deidra kept insisting she didn't want a boy, and even told him that she was aware of his age. When he proposed to her dad in a pub, she kept mum, even made a video which she just took as proof. However the happy couple didn't share the party joy they just now realized. After being 'forced' by Dey to get tested by several medical professionals, Leete was 'caught from step one' - the doctor who was taking in the baby - but with another baby shower complete. It's now a bit of a bumpy road. Deidra had planned to tell Dey the baby hasn't arrived, but then accidentally took a small pill which cured Leete. He was 'not happy' having the baby declared healthy, but that changed before Leete could tell anyone. But now Deidra's baby finally emerges. Dey's heart continues to beat and Deidra has no longer a need for a surrogate mother
#
# [24100 | 30215.53] loss=1.34 avg=2.13
# [24200 | 30340.56] loss=2.09 avg=2.13
# [24300 | 30465.52] loss=1.33 avg=2.12
# [24400 | 30590.48] loss=2.04 avg=2.12
# [24500 | 30715.44] loss=1.95 avg=2.12
# [24600 | 30840.40] loss=2.13 avg=2.12
# [24700 | 30965.41] loss=1.40 avg=2.11
# [24800 | 31090.41] loss=1.81 avg=2.11
# [24900 | 31215.37] loss=2.45 avg=2.11
# [25000 | 31340.40] loss=1.80 avg=2.11
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-25000
# ======== SAMPLE 1 ========
#  David, also in debt to Yuma, whom she takes out on a client's fiancée. But his arrival in this hellish country isn't everything. On the one hand, the money is all that matters, and his family are extremely anxious to help him. But on the other, they are also living characters, and will be left holding in horrible suspense, each desperate to the delivery that the other is delivering. The rest of the series is a brutal, multi-part story... set against the backdrop of a very different world. Set twenty years after a dramatic and violent crossroads in the history of Britain, the two most important events in history unite to create a single, powerful and well-written epic tale. Michael Caine (Cain and Evans) is a well-read former soldier, writer and amateur dramaturgist who has his sights set firmly on independence and the idea of a just global society. With his faithful girlfriend Rebecca Van Clever (Davies) he's up against the odds but inevitably learns to overcome his limited resources and enemies to achieve his dream of a just world.<|endoftext|>
# <|startoftext|>drama|0|"A Comicbook Fitz" (2009)|1| "
#
# [25100 | 31470.85] loss=2.19 avg=2.11
# [25200 | 31595.89] loss=2.02 avg=2.11
# [25300 | 31720.94] loss=2.19 avg=2.11
# [25400 | 31846.01] loss=1.79 avg=2.11
# [25500 | 31971.11] loss=1.29 avg=2.10
# [25600 | 32096.19] loss=1.80 avg=2.09
# [25700 | 32221.29] loss=2.19 avg=2.10
# [25800 | 32346.38] loss=1.50 avg=2.09
# [25900 | 32471.51] loss=1.70 avg=2.08
# [26000 | 32596.57] loss=1.19 avg=2.08
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-26000
# ======== SAMPLE 1 ========
# |0|"Tough Nails" (2007) {The Heartbreak (#1.1)}|1| In 1905, a fire destroys the old castle of St. Albans forever and no-one really knows how to save a man and his baby from its destruction. Three loner brothers and Billie Jenkins survive a world disaster and stumble upon an undersea way station: the heartbreak-aided which sees the boys forced to live on the island where they discover what life was like; while they're at the castle, one, Billie Jenkins, is the first to die in the disaster.<|endoftext|>
# <|startoftext|>sci-fi|0|"Teeny, Tokky & Tokky: Love Me Tastrophe" (2012)|1| A single mother, star of "Star Trek" fame, is confronted with the shocking news that she is no longer the most popular girl in school. To deal with the pressure, the mother, who has her own television show and a television career as a child actress, takes drastic measures in order to finally admit her feelings toward a boy. Meanwhile, in a world where boys' emotions get the better of them, the mother must also deal with the threat
#
# [26100 | 32727.22] loss=1.84 avg=2.07
# [26200 | 32852.34] loss=1.86 avg=2.07
# [26300 | 32977.44] loss=2.24 avg=2.07
# [26400 | 33102.52] loss=1.44 avg=2.07
# [26500 | 33227.59] loss=2.01 avg=2.06
# [26600 | 33352.69] loss=1.99 avg=2.06
# [26700 | 33477.76] loss=2.18 avg=2.07
# [26800 | 33602.81] loss=1.16 avg=2.06
# [26900 | 33727.83] loss=1.91 avg=2.05
# [27000 | 33852.87] loss=1.79 avg=2.05
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-27000
# ======== SAMPLE 1 ========
#  the last few years in New York, and he gets a surprise from a real life friend. Meanwhile, the mayor is a little concerned that his old nemesis, the powerful "Mayor Pawter", is getting tired of his reign and takes a well deserved vacation to Long Island. It's off to a local beachcomber with Pawter's pretty girlfriend, a shy young girl and a beautiful, blond babe.<|endoftext|>
# <|startoftext|>comedy|0|"I Want to Call My Friend" (2011) {Welcome to the New City (#2.1)}|1| As promised, this episode of I Want to Call My Friend features live action from the town of Chicago, the world's largest P2P app that will make your life easier. It's an instant internet success, but it's a short lived one. We'll take you to a meeting of the Apple App Store, an adventure by the Ice Cream Parlor and an auction in the basement of the biggest ice cream shop in America and then discover a surprise in the windy streets of Chicago.<|endoftext|>
# <|startoftext|>comedy|0|"I Feel Like a Weirdo" (2010)
#
# [27100 | 33984.87] loss=2.26 avg=2.05
# [27200 | 34110.02] loss=2.27 avg=2.06
# [27300 | 34235.08] loss=1.74 avg=2.05
# [27400 | 34360.25] loss=1.53 avg=2.05
# [27500 | 34485.26] loss=1.96 avg=2.05
# [27600 | 34610.33] loss=1.93 avg=2.04
# [27700 | 34735.46] loss=1.60 avg=2.04
# [27800 | 34860.58] loss=1.54 avg=2.03
# [27900 | 34985.69] loss=1.47 avg=2.03
# [28000 | 35110.84] loss=1.85 avg=2.03
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-28000
# ======== SAMPLE 1 ========
#  words on who to believe when we read about a '60s ghost movie...or a '40s ghost opera "What a Tangled Web You Get (#4.4)}|1| It may sound harsh on your close the family...but the town you end up visiting is the one you'll remember for as the series goes on. A group of eight 30-something guys who find themselves in a group home together are led to believe that they are in a ghost town and decide to set out to live there, despite their limited knowledge of the legend. It all starts when they stumble upon a mysterious clue telling them that they will be send to a ghost town where they will be sent back in time to their 1930s hometown if they get 10 grand by the end of the week. They begin to realize that there's more to the town than meets the eye with creepy-looking people, abandoned houses that are currently haunted by the same ghost they believed to be lurking outside, and strange ghosts that are magically linked to bats. Of course, with so many twists and turns, you won't want to miss this one.<|endoftext|>
# <|startoftext|>horror|0|"Fear and Loathing in Surreality" (2010
#
# [28100 | 35241.44] loss=1.17 avg=2.02
# [28200 | 35366.57] loss=0.88 avg=2.01
# [28300 | 35491.63] loss=1.74 avg=2.00
# [28400 | 35616.78] loss=1.62 avg=2.00
# [28500 | 35741.86] loss=2.25 avg=2.00
# [28600 | 35866.94] loss=1.48 avg=2.00
# [28700 | 35992.10] loss=1.21 avg=1.99
# [28800 | 36117.30] loss=2.07 avg=1.99
# [28900 | 36242.42] loss=1.85 avg=1.99
# [29000 | 36367.57] loss=2.04 avg=1.99
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-29000
# ======== SAMPLE 1 ========
# .5)}|1| After an attempted suicide, Jake gets arrested and is asked to testify at the trial. After being questioned that the truth was out and that he was in jail, Jake is thrown into jail. Jake tells the judge why he couldn't help the son. He finds out that the judge was not there but when they go to the prison to file official material, Jake is there. They try to bring Jake before the judge before he hears his opinion. But there is just too much pressure for a lawyer like Jack to get his opinion. But the judge is not in everyone's favor. So she decides to get back to him.<|endoftext|>
# <|startoftext|>horror|0|"The Mentalist" (2008) {Dead Again (#1.7)}|1| The family of Johnathan Begel, a New Orleans accountant, arrives in San Francisco. Johnathan's business partner and fiancée Joanne is there, too. Joanne is planning to sell the business to save some major businesses and Johnathan tells Jack to keep Joanne in his company. Jack informs them about the death of one of Johnathan's investors when he found out she was working with his firm. So he asks
#
# [29100 | 36498.24] loss=1.48 avg=1.98
# [29200 | 36623.41] loss=1.50 avg=1.98
# [29300 | 36748.61] loss=2.15 avg=1.98
# [29400 | 36873.78] loss=2.17 avg=1.98
# [29500 | 36998.93] loss=1.65 avg=1.98
# [29600 | 37124.06] loss=2.03 avg=1.98
# [29700 | 37249.22] loss=1.98 avg=1.98
# [29800 | 37374.35] loss=1.50 avg=1.97
# [29900 | 37499.49] loss=1.58 avg=1.97
# [30000 | 37624.60] loss=1.71 avg=1.97
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-30000
# ======== SAMPLE 1 ========
# 's back for a surprise. But things go terribly wrong when she gets the wrong date. When Simon, Dave and Jeff decide to have an epic double date, they have to decide who should control their romantic futures.<|endoftext|>
# <|startoftext|>fantasy|0|"Vorc" (2017) {The Unkindest Suitor (#1.2)}|1| After a terrifying encounter with an unexpected stranger, Raimundo, who is unable to contact his parents, is forced to defend him and their unborn child as they navigate the bizarre world after the encounter. With the help of Knaan, a young doctor, the women must come face to face with the most shocking and shocking events in their mysterious world.<|endoftext|>
# <|startoftext|>fantasy|0|"Vecinos" (2009)|1| An adventure in the interwoven lives of Maxim, Josef and Anton, through the years of life in Cabrillo de Seyro, Mexico, where their families lived together. Life went on: the great war, the big money change of becoming rich and working hard while pursuing all means of success. And everything changed for the different people that lived
#
# [30100 | 37756.52] loss=1.33 avg=1.96
# [30200 | 37881.61] loss=1.62 avg=1.96
# [30300 | 38006.70] loss=1.33 avg=1.95
# [30400 | 38131.82] loss=1.98 avg=1.95
# [30500 | 38256.92] loss=2.26 avg=1.95
# [30600 | 38382.09] loss=1.97 avg=1.95
# [30700 | 38507.23] loss=1.33 avg=1.95
# [30800 | 38632.33] loss=0.68 avg=1.93
# [30900 | 38757.46] loss=1.17 avg=1.92
# [31000 | 38882.54] loss=2.59 avg=1.93
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-31000
# ======== SAMPLE 1 ========
#  Z's dad has been murdered and as his spirit runs wild and makes it's way to him he goes to Dr. Hayward and tells him he may have the solution to the crime and needs to try. Later the doctor tells him that he has been working on solving the case but with a big difference and a new partner none of them have expected.<|endoftext|>
# <|startoftext|>crime|0|"Jekyll For Tomorrow" (1979) {Jekyll and the City: Part 2 (#1.4)}|1| Mr. Willet gets Jeekyll released from prison which leads him to work with the CIA to save the city. When a government representative is thrown out of the building, then replaced by someone who is only phased by the fog, Jeekyll makes his rounds at the Jekyll-and-the-earth Club and then at Jekyll's Table.<|endoftext|>
# <|startoftext|>crime|0|"Jane Eyre Mysteries" (1998)|1| Four women, each attending a different school and college, go through a variety of time related events, each with different ideas on how to go forward with their own paths. Some students make
#
# [31100 | 39013.21] loss=1.37 avg=1.93
# [31200 | 39138.31] loss=1.60 avg=1.92
# [31300 | 39263.40] loss=2.45 avg=1.93
# [31400 | 39388.41] loss=1.81 avg=1.93
# [31500 | 39513.30] loss=1.35 avg=1.92
# [31600 | 39638.11] loss=1.34 avg=1.91
# [31700 | 39762.96] loss=1.50 avg=1.91
# [31800 | 39888.03] loss=1.78 avg=1.91
# [31900 | 40013.13] loss=1.99 avg=1.91
# [32000 | 40138.23] loss=0.97 avg=1.90
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-32000
# ======== SAMPLE 1 ========
#  hot and have to deal with the ghosts of a most haunting of all - ghosts that will never be exorcised. And, to wrap up a rather unpleasant episode for both of them, The Phantom Avenger is visiting their childhood home, a home which becomes a studio and playhouse, just as the playhouse begins to dismantle itself.<|endoftext|>
# <|startoftext|>comedy|0|"The Phantom Avenger" (2006) {The Great Cat Family Negotiation (#1.18)}|1| After a grudge against Cat Week, The Phantom Avenger must now become a grumpy bachelor. But he's not the only one bearing a grudge. Cat Week nearby as he makes his move to coerce forgiveness in front of Cat's loyal butler friend Jimmy.<|endoftext|>
# <|startoftext|>comedy|0|"The Phantom Avenger" (2006) {Wake Me Up Before You Go-Go (#1.5)}|1| On this episode, the Phantom Avenger meets a young man who he encounters asking to be his proxy in a cat-fight between a group of thieves blinded by greed. Later, the thieves take on an all-Spanish red kitty named Ronaldinho
#
# [32100 | 40269.11] loss=1.51 avg=1.90
# [32200 | 40394.30] loss=2.00 avg=1.90
# [32300 | 40519.42] loss=1.25 avg=1.89
# [32400 | 40644.55] loss=0.87 avg=1.88
# [32500 | 40769.68] loss=1.69 avg=1.88
# [32600 | 40894.87] loss=1.36 avg=1.87
# [32700 | 41020.03] loss=1.07 avg=1.86
# [32800 | 41145.19] loss=1.06 avg=1.86
# [32900 | 41270.34] loss=1.29 avg=1.85
# [33000 | 41395.45] loss=0.77 avg=1.84
# Saving drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-33000
# ======== SAMPLE 1 ========
# ert is still missing with the suitcase and the ransom money is missing too. And if Frank was about to kill him, Leo has a hard time believing Frank anymore because the evidence is completely against him.<|endoftext|>
# <|startoftext|>thriller|0|"White Collar" (2009) {Pilot (#1.1)}|1| After selling shares trading at one twelve seven hundred ninety-eight dollars an "Underly wealthy" widow named Carrie Quinn is kidnapped by her husband, Jesse. Carrie's bodyguard, Julian McQuark, discovers her hidden talents as a chess expert in the guise of black-sheared black antiques, and Carrie refuses to believe Julian has something that he does not know and poisons Pepper Ramin as well.<|endoftext|>
# <|startoftext|>thriller|0|"White Collar" (2009) {Raising the price (#2.1)}|1| As business Jeff Beck joins forces with the new Federal Witness liaison, the team travels to San Diego to a high-rise, hoping to find a briefcase that they could use to take on a drug deal gone bad. Meanwhile, Dana and Marty's romance heats up,
#
# [33100 | 41526.07] loss=1.53 avg=1.84
# [33200 | 41651.19] loss=1.28 avg=1.83
# [33300 | 41776.37] loss=2.02 avg=1.83
# [33400 | 41901.53] loss=1.72 avg=1.83

# %%
# !cp -r "models/$MODEL_NAME/hparams.json" "$CHECKPOINT_DIR/run1"
# !cp -r "models/$MODEL_NAME/encoder.json" "$CHECKPOINT_DIR/run1"

# %% [markdown]
# ## Generate dumps

# %%
sess = gpt2.start_tf_sess()

gpt2.load_gpt2(sess, checkpoint_dir=CHECKPOINT_DIR)
# Out:
# Loading checkpoint drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-30000
# INFO:tensorflow:Restoring parameters from drive/My Drive/Colab Notebooks/transformers/MoviePlots/text_generation/GPT-2-gpt2simple/checkpoint/run1/model-30000

# %%
def generate_dump(prompt, num_samples, temp, top_p):
    """Generate a dump of samples.
    Inspired by https://github.com/minimaxir/hacker-news-gpt-2"""
    
    samples = gpt2.generate(sess,
                            checkpoint_dir=str(CHECKPOINT_DIR),
                            truncate=False,
                            prefix=prompt,
                            seed=SEED,
                            nsamples=num_samples,
                            batch_size=num_samples,
                            length=256,
                            temperature=temp,
                            top_p=top_p,
                            include_prefix=True,
                            return_as_list=True)
    return samples

# %%
generate_dump(BOS_TOKEN + 'horror' + EOG_TOKEN, 10, 1, 0)
# Out:
# ['<|startoftext|>horror~#~"Life After" (2009) {Romancing the Feat (#1.3)}$$$ Eddie meets "The Bullfighter" - a school bully who likes all his boys (Because boys need bullies too) - before building a beef between the two. The bullies find his nerdy younger brother, Jake, and move in with the older girls. The older girls like Jake, but Eddie\'s smitten by Jake. Actually Jake\'s rhyming anko is well earned.<|endoftext|>\n<|startoftext|>War~#~"The Tudors" (2007) {Queen\'s Own (#1.1)}$$$ In her own right, the Queen succumbs at first, but through the Tudor Succession, she grows just as wrong and has a private court trial only to win an appeal. Henry Tudor spends most of his time in France tending to his woman, Mary Boleyn sticks to her man and Jane Is foretold in marriage. In the south and west, the church is founded and the blame for the Spanish Civil War is laid at the feet of James I. The catholic led \'Titanic balance\' between church and state is broken when Cromwell is elected Holy Germaine, angry that his',
#  '<|startoftext|>horror~#~"1000 Ways to Die" (2008) {Bloody Mad (#3.2)}$$$ 1000 Ways to Die looks at the following cases: "#JAIL ISLAND is a JAN-STAMPing Murder" examines the rape and sodomy of a university campus worker, "#JULA-STAMPing Murder" a man who slept around since 8 hours, "#DOCTOR STRANGE-On Faith-less Tomb" a former Marine who raped and killed a woman who profited from her PTSD, "#PETTISTERIA-The Encutting of the Virgin of sin" a cell hand who survived a heart attack after she overdosed, "#PETTISTERIA-Custody of the Week" a man who had a conviction for possession of stolen property, "#GREEN-Metal Stimulant" a FL battery victim who overdosed when she was heated for interrupting her work, "#SDiKE-Circles-and-Slip-A-Mole" a pungent pigeon who got 14 stitches on his leg, "#SDiKE-Circles-and-Slip-A-Mortal" a cyper who had a conviction for possession of seven parasites, "#5G-Pro-Pro-Chem',
#  '<|startoftext|>horror~#~"Bates Motel" (2013) {Presumed Innocent (#2.1)}$$$ After the death of Norman, Norma is certain he has been murdered. But who and why exactly? Sheriff Romero turns to Emma White for help. Norman tells Norma that his uncle was killed by a man named Dan Mathews, who is now a big city lawyer. In his sleep, Dan begins to predict Norman\'s next action. There are new crimes to investigate - all connected to the mysterious Apache woman who seems to be living in Norman\'s dreams. Meanwhile, back at the base, Dylan confides in Emma what\'s seem on the surface, but she dismisses it as being Dylan\'s fault.<|endoftext|>\n<|startoftext|>Talk-Show~#~"Moyers & Company" (2012) {Piling Planters (#2.25)}$$$ Bill Moyers begins 2011 with a plea for funds that\'s raised from property investors and also from the average homeowner. Bill then addresses the mortgage crisis in Michigan and his believes that government can no longer dictate homeowners terms of service. He offers two Mom and Pop properties bought and a limited finance guarantee. Callie Gatherwood owns a boat and airplane business called She',
#  '<|startoftext|>horror~#~"The F.B.I. Files" (1998) {The Price of Greed (#3.14)}$$$ In 1992, a Serbian immigrant and purpose built college teacher, Vovan Beorya, was brutally murdered and robbed in his apartment. Weeks later, a Customs official in charge investigated. Beorya\'s daughter vowed never forget her father and begged FBI Agent Christine Butler to send him in to stop the crime.<|endoftext|>\n<|startoftext|>News~#~"20/20" (1978) {Prince George of Egypt: Three Girls Sent to Capitalize Murder (#39.16)}$$$ 20/20 goes to D.C. TO SEND ON ANOTHER ONE! FRANKENSTEIN : Five juvenile daughters are unaccounted for over a decade, in witness protection. Troop WO\'ELYN varies his plea for a possessive mother and sues him for $135 million. FANNY KAZBEL: She says she left her missing grandfather Bobicia and is in deep trouble. However, her attorney says that, because of her reputation, she can\'t get warrant to search her home.<|endoftext|>\n<|startoftext|>Crime',
#  '<|startoftext|>horror~#~"Steins;Gate" (2011) {Mother Verdict; Artificial Intelligence (#1.4)}$$$ In the 3rd episode Capital of Olympus, Athena was granted a new trial by firing time machine. Sasame, who had disregarded the ruling several times, tried twice for the abortion of the little girl he loved, rendering her incapable for her second opinion. The obstinate judge decided to trial the remaining jurors individually, clearly dismissing the individual for pastirizing them, a practice that the army continued to monitor. With super-human strength and superior military technology, the army was able to ascertain the truth when and where it was hidden. Meanwhile, Psychodramatic interferes with both the actual trial and the vote by allowing each of the interrogators to select their own jury as the "corpse count". Despite his earlier warning over morphers, Spike refuses to continue \'treatment\' with the Stimulant drug, but his earlier choice for the most dangerous convict is Mikawa, who pulled the plug after Pike deliberately allowed a trap set by the army, and keeps sneaking into the trial.<|endoftext|>\n<|startoftext|>Western~#~"Gunsmoke" (1955) {Gulliper (#',
#  '<|startoftext|>horror~#~"Immortal Grandmurs" (1998)$$$ This MV (Monster/Teacher\'s Laughter) is comprised of 14 episodes and consisted of 14 short part-time episodes. The episodes were portrayed by the School Director Ayutchan Suzuki and Social Media Manager Yuki Nishizaki, who portrayed the students in their typical respectful respectful ways much to the shock of the teachers, staff and parents of the deaf children.<|endoftext|>\n<|startoftext|>Action~#~"Spider-Man" (1967) {Cage of Steel (#3.6)}$$$ A monster known as "Super Steel" is attacking a city, stealing power from the rich and\\or destroying televisions. The Fantastic Four are captured by Steel and his minions to prevent his crimes. But supervillains take note of the Foursome\'s actions and think they are being tipped off by a bank. The Fantastic Four must\\or something to that effect to save the day.<|endoftext|>\n<|startoftext|>Drama~#~"Periodistas" (1998) {Luz de luna (#8.5)}$$$ Ana has made a decision and goes to a rehabilitation center in order to',
#  '<|startoftext|>horror~#~"Murdoch Mysteries" (2008) {Life Goes On, Go On, Go! (#7.5)}$$$ Detective Murdoch investigates the murder of Edward Haslemere who walked away from his job a month and a half after taking his own life. At the time he was head jockey for the job with Julia Craig who was appointed head of the local abbey. Constable Crabtree learns Edward had an affair with ex-mistress Clara Randol. His successor Denise Worsley befriends Edward. With Dr. Simon Mayhew following them, where Julia tells him that Edward admired Clara\'s older sister Jessica and not Edward. Having been tipped off by an anonymous tip, Murdoch investigates claims that Clara fled to New York to escape the wrath of her absent husband Errol. She does not escape in disguise but is recognized by someone. Their next victim is Clara Randol who left her native Wellington penniless and never showed up at the station to see her brother. Murdoch is also noticed over the $12,000 in cash found in a locked van, $10,000 that belongs to her father. Later she is found dead and a large bag stuffed with cash proceeds from her exit is found at the scene of her murder. Fanatics are called in to',
#  '<|startoftext|>horror~#~"Siberia" (2013) {How the Booby trappedYou (#2.3)}$$$ A strange company is testing a mega-hazardous discharge, and they seem to know about Samuel. Meanwhile, Neotia is getting restless. Andi tries to sleep. Johnny and Sam discover that something isn\'t right in the morgue.<|endoftext|>\n<|startoftext|>Comedy~#~"Benidorm" (2007) {(#2.3)}$$$ Nickie meets his son Trevor and plots revenge against him. Bruno- tries to hide his secret from Aunt Pru. Jan\'s home life interferes with working at \'Seafood\' and Redknapp\'s bedsit. Tommy\'s mother is found forced to leave him by a woman who takes him back to Rupert\'s and tells him that she wants to marry an Archbishop. Claude eagerly takes the new community centre-amp,though the Minnie signs the slip-up project,which will let her profits blanket to the rest of the village.<|endoftext|>\n<|startoftext|>Documentary~#~"Top Gear USA" (2008) {Grand Cherokee (#4.12)}$$$ Sny',
#  '<|startoftext|>horror~#~"Ruth Rendell Mysteries" (1987) {Vanity Must Be Obsessed (#1.1)}$$$ The vicar and his wife are engaged and the vicar announces that his wife will move in if the marriage is serious. When Peter\'s efforts to impress a girl spate the family Edith Rivers puts him through a humiliating initiation into a sex club. Peter eventually becomes a self obsessed vampire but when his efforts to rein him in don\'t succeed the temptation in the form of the parties that Becky Rivers attends next door leads him to trip up Foyle\'s and she to ruin him. A friend of Foyle tries to warn him against going into the sex club but in the end he comes round.<|endoftext|>\n<|startoftext|>Drama~#~"Medium" (2005) {Wicked Game: Part Two (#4.24)}$$$ Allison continues to dream about Cynthia Keener\'s daughter, Cynthia (phanescence being part of the term she use to describe her exceptional abilities in children\'s science classes). Cynthia is crushed when two of her classmates, Cynthia co-founder and schoollibrarian help her dream CIs. One of them, Norma Jean (guest appearance by Patrick Fitzgerald) gives young',
#  '<|startoftext|>horror~#~"Naked City" (1958) {The Mr Morano Story (#3.12)}$$$ Black smoke rises from chimney smoke. A young man trying to sell his weedy deluxe apartment southeast comes into the crossfire of a troubled man from years past, the true story of a hot shot Texan who swallowed half a candelabrum belonging to a fireman from New York City. The man offers the facts, but leaves them unresolved - until 1940, when a similar candelabrum was delivered in occupied Richmond, Kentucky.<|endoftext|>\n<|startoftext|>Drama~#~"Mission: Impossible" (1966) {The Acting President (#5.24)}$$$ When the IMF\'s favorite scapegoat is proclaimed the President of the United States, head of the Federal Republic of Venezuela Esther Ravez, the IMF brainee helps corrupt the government and stage a coup to make him believe the people have overthrown the long suffering president. The only way to get the President to relinquish his seat in the government is for the coup to create a secret Cabinet of the FOMC which must be run conversely to the government. Now the team must create a lie-fest in order to make the']

# %%
def save_dumps():
    """Generate dumps of samples and save them to disk."""
    pbar = tqdm(total=len(GENRES)*len(TEMPS)*len(TOP_PS), desc="Dumps")
    for temp in TEMPS:
        for top_p in TOP_PS:
            samples = []
            for genre in GENRES:
                prompt = BOS_TOKEN + genre.lower() + EOG_TOKEN
                dump = generate_dump(prompt, NUM_SAMPLES_PER_GENRE, temp, top_p)
                for sample in dump:
                    samples.append(prompt + sample.split(EOS_TOKEN)[0] + "\n")
                pbar.update()
            fn = 'temp_%s_topp_%s.txt' % (str(temp).replace('.', '_'), 
                                          str(top_p).replace('.', '_'))
            with open(DUMPS_DIR/fn, 'w') as f:
                f.writelines(samples)
    pbar.close()

# %%
save_dumps()
# Out:
# Dumps:   0%|          | 0/168 [00:00<?, ?it/s]
# Dumps:   1%|          | 1/168 [00:51<2:24:25, 51.89s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-da942f13f00c> in <module>()
# ----> 1 save_dumps()
#
# <ipython-input-37-718158321640> in save_dumps()
#       7             for genre in GENRES:
#       8                 prompt = BOS_TOKEN + genre.lower() + EOG_TOKEN
# ----> 9                 dump = generate_dump(prompt, NUM_SAMPLES_PER_GENRE, temp, top_p)
#      10                 for sample in dump:
#      11                     samples.append(prompt + sample.split(EOS_TOKEN)[0] + "\n")
#
# <ipython-input-32-2f62ca2ca07c> in generate_dump(prompt, num_samples, temp, top_p)
#      14                             top_p=top_p,
#      15                             include_prefix=True,
# ---> 16                             return_as_list=True)
#      17     return samples
#
# /usr/local/lib/python3.6/dist-packages/gpt_2_simple/gpt_2.py in generate(sess, run_name, checkpoint_dir, model_name, model_dir, sample_dir, return_as_list, truncate, destination_path, sample_delim, prefix, seed, nsamples, batch_size, length, temperature, top_k, top_p, include_prefix)
#     449         else:
#     450             out = sess.run(output, feed_dict={
# --> 451                     context: batch_size * [context_tokens]
#     452                 })
#     453         for i in range(batch_size):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1363   def _do_call(self, fn, *args):
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#    1367       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#    1352     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1441     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#    1445   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
